# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import sys
import random
from pomegranate import *
from hmm_visualization_methods import *
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import json
import os
import matplotlib.pyplot as plt
import seaborn as sns

# File paths
file_path_base_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_nb_saved_splits\metrics.json"
file_path_base_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_randomes\metrics.json"
file_path_new_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_nb\metrics.json"
file_path_new_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_randomes\metrics.json"
file_path_mhcpred = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\2\10fold\10foldmetrics.json"
files = [file_path_base_nb, file_path_base_r, file_path_new_nb, file_path_new_r, file_path_mhcpred]

# %%
import pandas as pd
from sklearn.metrics import roc_curve, auc
import os
import json
import subprocess

# MixMHC2pred functions
def MixMHC2pred_for_allele(allele, input_file, output_file):
    mixmhc2pred_path = "C:\\Tools\\MixMHC2pred-2.0\\MixMHC2pred.exe"
    
    command = [
        mixmhc2pred_path,
        "-i", input_file,
        "-o", output_file,
        "-a", allele,
        "--no_context"  
    ]
    try:
        subprocess.run(command, check=True)
        print(f"Prediction completed! Results saved in {output_file}")
    except subprocess.CalledProcessError as e:
        print(f"Error occurred: {e}")

def is_binder_mhc_pred(file_path, allele, target_path, ind, threshold=5.0):
    def read_mixmhc2pred_file(file_path):
        with open(file_path, 'r') as file:
            lines = file.readlines()
        start_line = next(i for i, line in enumerate(lines) if not line.startswith('#'))
        df = pd.read_csv(file_path, skiprows=start_line, delimiter='\t')
        return df

    df = read_mixmhc2pred_file(file_path)
    df['Binder'] = df.apply(
        lambda row: '1' if (row[f"%Rank_{allele}"] < threshold) else '0',
        axis=1
    )

    output_file = os.path.join(target_path, f'classified_peptides_{allele}-{ind}.csv')
    df.to_csv(output_file, index=False)
    print(f"Prediction completed! Results saved in {output_file}")
    return df

# Function to format allele name
def format_allele_name(allele):
    allele_formatted = allele.replace("HLA-", "")  # Remove 'HLA-'
    allele_formatted = allele_formatted.replace("-", "")  # Replace '-' with ''
    
    parts = allele_formatted.split('DRB')
    formatted_allele = f"DRB{parts[1][0:1]}_{parts[1][1:3]}_{parts[1][3:]}"
    return formatted_allele

def load_y_test(allele, fold, peptide_length):
    y_test_path = rf"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_nb_saved_splits\{allele}\fold_{fold}\test_data.csv"
    y_test_df = pd.read_csv(y_test_path)
    
    # Filter y_test based on peptide length
    if peptide_length != 'all':
        y_test_df = y_test_df[y_test_df['peptide'].apply(lambda x: len(x) == peptide_length)]
    else:
        y_test_df = y_test_df[y_test_df['peptide'].apply(lambda x: len(x) >= 12)]
    
    return y_test_df

def run_mixmhc(allele, fold, target_path_allele, peptide_length):
    allele_formatted = allele.replace("HLA-", "").replace("-", "")
    parts = allele_formatted.split('DRB')
    formatted_allele = f"DRB{parts[1][0:1]}_{parts[1][1:3]}_{parts[1][3:]}"
    
    y_test_df = load_y_test(allele, fold, peptide_length)
    test_file = os.path.join(target_path_allele, f"test_peptides_{fold}.txt")
    y_test_df["peptide"].to_csv(test_file, index=False, header=False)
    
    output_file = os.path.join(target_path_allele, f"mixmhc2pred_results_{fold}.txt")
    MixMHC2pred_for_allele(formatted_allele, test_file, output_file)
    
    if not os.path.exists(output_file):
        raise FileNotFoundError(f"MixMHC2pred output file not found: {output_file}")
    
    df_pred = is_binder_mhc_pred(output_file, formatted_allele, target_path_allele, fold)
    return (100 - df_pred[f"%Rank_{formatted_allele}"]).to_list()

# Initialize dictionary for storing results
metrics_dict = {}

alleles = [
    'HLA-DRB1*03:01', 'HLA-DRB3*01:01', 'HLA-DRB1*07:01',
    'HLA-DRB1*11:01', 'HLA-DRB1*12:01', 'HLA-DRB1*15:01',
    'HLA-DRB4*01:01', 'HLA-DRB3*02:02', 'HLA-DRB5*01:01', 'HLA-DRB1*01:01'
]
peptide_lengths = ['all']

target_path_allele = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output"

for allele in alleles:
    allele_formatted = allele.replace(":", "-").replace("*", "").replace("/", "_")
    metrics_dict[allele_formatted] = {}
    
    for peptide_length in peptide_lengths:
        metrics_dict[allele_formatted][peptide_length] = {}
        
        for fold in range(1, 11):
            y_test_df = load_y_test(allele_formatted, fold, peptide_length)
            y_test = y_test_df['label']
            
            mixmhc_scores = run_mixmhc(allele_formatted, fold, target_path_allele, peptide_length)
            
            fpr, tpr, _ = roc_curve(y_test, mixmhc_scores)
            roc_auc = auc(fpr, tpr)
            
            metrics_dict[allele_formatted][peptide_length][fold] = {
                "auc": roc_auc,
                "fpr": fpr.tolist(),
                "tpr": tpr.tolist()
            }

# Save metrics dictionary
metrics_path = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc_metrics.json"
with open(metrics_path, "w") as f:
    json.dump(metrics_dict, f, indent=4)

print(f"Metrics saved to {metrics_path}")
# Out:
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_1.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_03_01-1.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_2.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_03_01-2.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_3.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_03_01-3.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_4.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_03_01-4.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_5.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_03_01-5.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_6.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_03_01-6.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_7.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_03_01-7.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_8.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_03_01-8.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_9.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_03_01-9.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_10.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_03_01-10.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_1.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_01_01-1.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_2.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_01_01-2.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_3.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_01_01-3.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_4.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_01_01-4.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_5.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_01_01-5.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_6.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_01_01-6.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_7.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_01_01-7.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_8.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_01_01-8.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_9.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_01_01-9.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_10.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_01_01-10.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_1.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_07_01-1.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_2.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_07_01-2.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_3.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_07_01-3.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_4.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_07_01-4.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_5.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_07_01-5.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_6.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_07_01-6.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_7.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_07_01-7.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_8.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_07_01-8.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_9.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_07_01-9.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_10.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_07_01-10.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_1.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_11_01-1.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_2.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_11_01-2.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_3.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_11_01-3.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_4.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_11_01-4.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_5.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_11_01-5.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_6.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_11_01-6.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_7.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_11_01-7.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_8.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_11_01-8.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_9.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_11_01-9.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_10.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_11_01-10.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_1.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_12_01-1.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_2.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_12_01-2.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_3.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_12_01-3.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_4.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_12_01-4.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_5.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_12_01-5.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_6.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_12_01-6.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_7.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_12_01-7.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_8.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_12_01-8.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_9.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_12_01-9.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_10.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_12_01-10.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_1.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_15_01-1.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_2.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_15_01-2.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_3.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_15_01-3.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_4.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_15_01-4.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_5.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_15_01-5.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_6.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_15_01-6.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_7.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_15_01-7.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_8.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_15_01-8.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_9.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_15_01-9.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_10.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_15_01-10.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_1.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB4_01_01-1.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_2.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB4_01_01-2.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_3.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB4_01_01-3.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_4.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB4_01_01-4.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_5.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB4_01_01-5.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_6.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB4_01_01-6.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_7.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB4_01_01-7.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_8.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB4_01_01-8.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_9.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB4_01_01-9.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_10.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB4_01_01-10.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_1.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_02_02-1.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_2.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_02_02-2.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_3.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_02_02-3.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_4.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_02_02-4.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_5.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_02_02-5.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_6.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_02_02-6.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_7.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_02_02-7.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_8.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_02_02-8.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_9.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_02_02-9.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_10.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB3_02_02-10.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_1.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB5_01_01-1.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_2.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB5_01_01-2.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_3.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB5_01_01-3.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_4.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB5_01_01-4.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_5.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB5_01_01-5.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_6.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB5_01_01-6.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_7.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB5_01_01-7.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_8.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB5_01_01-8.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_9.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB5_01_01-9.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_10.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB5_01_01-10.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_1.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_01_01-1.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_2.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_01_01-2.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_3.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_01_01-3.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_4.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_01_01-4.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_5.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_01_01-5.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_6.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_01_01-6.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_7.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_01_01-7.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_8.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_01_01-8.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_9.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_01_01-9.csv
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc2pred_results_10.txt
# Prediction completed! Results saved in C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\classified_peptides_DRB1_01_01-10.csv
# Metrics saved to C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output\mixmhc_metrics.json

# %%
import pandas as pd
import json
from sklearn.metrics import roc_curve, auc, accuracy_score, precision_score, recall_score, f1_score
import os
from collections import defaultdict
def format_allele_name(allele):
    allele_formatted = allele.replace("HLA-", "")  # Remove 'HLA-'
    allele_formatted = allele_formatted.replace("-", "")  # Replace '-' with ''
    
    parts = allele_formatted.split('DRB')
    formatted_allele = f"DRB{parts[1][0:1]}_{parts[1][1:3]}_{parts[1][3:]}"
    return formatted_allele


def load_y_test(allele, fold, peptide_length):
    y_test_path = rf"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_nb_saved_splits\{allele}\fold_{fold}\test_data.csv"
    y_test_df = pd.read_csv(y_test_path)
    
    if peptide_length != 'all':
        y_test_df = y_test_df[y_test_df['peptide'].apply(lambda x: len(x) == peptide_length)]
    else:
        y_test_df = y_test_df[y_test_df['peptide'].apply(lambda x: len(x) >= 12)]
    
    return y_test_df

def load_saved_mixmhc_scores(allele, fold, target_path_allele):
    output_file = os.path.join(target_path_allele, f'classified_peptides_{allele}-{fold}.csv')
    if not os.path.exists(output_file):
        raise FileNotFoundError(f"Saved MixMHC output file not found: {output_file}")
    
    df_pred = pd.read_csv(output_file)
    scores = (100 - df_pred[f"%Rank_{allele}"]).to_list()
    return scores

def calculate_metrics(y_test, y_scores):
    fpr, tpr, _ = roc_curve(y_test, y_scores)
    auc_score = auc(fpr, tpr)
    accuracy = accuracy_score(y_test, [1 if score > 50 else 0 for score in y_scores])
    precision = precision_score(y_test, [1 if score > 50 else 0 for score in y_scores])
    recall = recall_score(y_test, [1 if score > 50 else 0 for score in y_scores])
    f1 = f1_score(y_test, [1 if score > 50 else 0 for score in y_scores])
    
    return {
        "auc_score": auc_score,
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1
    }


metrics_dict =  defaultdict(list)
alleles = ['HLA-DRB1*03:01',
           'HLA-DRB3*01:01',
           'HLA-DRB1*07:01',
           'HLA-DRB1*11:01',
           'HLA-DRB1*12:01',
           'HLA-DRB1*15:01',
           'HLA-DRB4*01:01',
           'HLA-DRB3*02:02',
           'HLA-DRB5*01:01',
           'HLA-DRB1*01:01'] 
peptide_lengths = ['all']

for allele in alleles:
    allele = allele.replace(":", "-").replace("*", "").replace("/", "_")
    allele_f = format_allele_name(allele)
    for peptide_length in peptide_lengths:
        for fold in range(1, 11):
            y_test_df = load_y_test(allele, fold, peptide_length)
            y_test = y_test_df['label']
            
            target_path_allele = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output"
            mixmhc_scores = load_saved_mixmhc_scores(allele_f, fold, target_path_allele)
            
            metrics = calculate_metrics(y_test, mixmhc_scores)
            metrics_dict[allele].append(metrics)

with open("mixmhc_metrics.json", "w") as f:
    json.dump(metrics_dict, f, indent=4)

# %%
import pandas as pd
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import os

# Function to load y_test (true labels)
def load_y_test(allele, fold, peptide_length):
    y_test_path = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_nb_saved_splits\{allele}\fold_{fold}\test_data.csv"
    y_test_file = y_test_path.format(allele=allele, fold=fold)
    y_test_df = pd.read_csv(y_test_file)

    # Filter y_test based on peptide length
    if peptide_length != 'all':
        y_test_df = y_test_df[y_test_df['peptide'].apply(lambda x: len(x) == peptide_length)]
    else:
        y_test_df = y_test_df[y_test_df['peptide'].apply(lambda x: len(x) >=12)]
    
    return y_test_df

# Function to load y_scores from a model's result file
def load_y_scores(file_path, peptide_length):
    try:
        df = pd.read_csv(file_path)
        if peptide_length != 'all':
            df = df[df['peptide'].apply(lambda x: len(x) == peptide_length)]
        else:
            df = df[df['peptide'].apply(lambda x: len(x) >=12)]
        
        # Debugging step: check if 'y_score' column exists
        if 'y_score' not in df.columns:
            print(f"Warning: 'y_score' column not found in {file_path}")
            return None  # Return None if the column is missing
        
        return df
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return None  # Return None if the file is missing

# Function to run MixMHC2pred
def run_mixmhc(allele, fold, target_path_allele, peptide_length):
    allele_formatted = allele.replace("HLA-", "")  # Remove 'HLA-'
    allele_formatted = allele_formatted.replace("-", "")  # Replace '-' with '_'
    parts = allele_formatted.split('DRB')
    formatted_allele = f"DRB{parts[1][0:1]}_{parts[1][1:3]}_{parts[1][3:]}"
    
    # Load test peptides
    y_test_df = load_y_test(allele, fold, peptide_length)
    test_file = os.path.join(target_path_allele, f"test_peptides_{fold}.txt")
    y_test_df["peptide"].to_csv(test_file, index=False, header=False)

    # Define output file for MixMHC
    output_file = os.path.join(target_path_allele, f"mixmhc2pred_results_{fold}.txt")
    
    # Call MixMHC2pred function (assumes it's defined elsewhere)
    MixMHC2pred_for_allele(formatted_allele, test_file, output_file)

    # Check if MixMHC output file exists
    if not os.path.exists(output_file):
        raise FileNotFoundError(f"MixMHC2pred output file not found: {output_file}")

    # Process MixMHC2pred results
    df_pred = is_binder_mhc_pred(output_file, formatted_allele, target_path_allele, fold)
    return (100 - df_pred[f"%Rank_{formatted_allele}"]).to_list()  # Return MixMHC scores

# Initialize the color map for models
model_colors = {
    'base_nb': 'blue',
    'base_r': 'green',
    'new_nb': 'red',
    'new_r': 'purple',
    'mixmhc': 'orange'
}

# List of alleles and peptide lengths
alleles = ['HLA-DRB1*03:01',
           'HLA-DRB3*01:01',
           'HLA-DRB1*07:01',
           'HLA-DRB1*11:01',
           'HLA-DRB1*12:01',
           'HLA-DRB1*15:01',
           'HLA-DRB4*01:01',
           'HLA-DRB3*02:02',
           'HLA-DRB5*01:01',
           'HLA-DRB1*01:01']  # Example alleles, replace with your list
peptide_lengths = [12, 15, 'all']

# Iterate over alleles and peptide lengths (k-mers)
for allele in alleles:
    allele = allele.replace(":", "-").replace("*", "").replace("/", "_")
    for peptide_length in peptide_lengths:
        plt.figure(figsize=(10, 8))  # Create a new plot for each allele and peptide length
        
        # Set a flag to track which models have already been added to the legend
        legend_added = {model: False for model in model_colors}
        
        # Iterate over folds
        for fold in range(1, 11):
            # Load true labels (y_test)
            y_test_df = load_y_test(allele, fold, peptide_length)
            y_test = y_test_df['label']

            # Define paths for each model (base_nb, base_r, new_nb, new_r)
            base_nb_path = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_nb_saved_splits\{allele}\fold_{fold_number}\y_scores.csv"
            base_r_path = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\random_model_natural_distr\{allele}\fold_{fold_number}\y_scores.csv"
            new_nb_path = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_natural_randomes\{allele}\fold_{fold_number}\y_scores_nb.csv"
            new_r_path = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_natural_randomes\{allele}\fold_{fold_number}\y_scores_r.csv"

            # Iterate over models
            for model_name, file_path_template in zip(['base_nb', 'base_r', 'new_nb', 'new_r'],
                                                      [base_nb_path, base_r_path, new_nb_path, new_r_path]):
                # Update file path with current allele and fold number
                file_path = file_path_template.format(allele=allele, fold_number=fold)

                # Load model's y_scores
                y_scores = load_y_scores(file_path, peptide_length)
                if y_scores is None or y_scores.empty:
                    continue  # Skip if y_scores couldn't be loaded or is empty
                
                # Ensure peptides in y_scores match those in y_test (align by peptide sequence)
                if len(y_test) != len(y_scores):
                    print(f"Warning: Mismatch in number of peptides between y_test and y_scores for {allele}, Fold {fold}, Peptide Length {peptide_length}")
                    print(f"y_test length: {len(y_test)}, y_scores length: {len(y_scores)}")
                    # Align the data based on peptide sequence
                    y_scores = y_scores[y_scores['peptide'].isin(y_test_df['peptide'])]
                    print(f"After alignment, y_scores length: {len(y_scores)}")

                # Ensure lengths match before calculating ROC
                if len(y_test) != len(y_scores):
                    print(f"Skipping {allele}, Fold {fold}, Length {peptide_length} due to length mismatch.")
                    continue

                # Calculate ROC curve
                fpr, tpr, _ = roc_curve(y_test, y_scores['y_score'])
                roc_auc = auc(fpr, tpr)

                # Plot the ROC curve for the current model
                plt.plot(fpr, tpr, color=model_colors[model_name], lw=2)

                # Add model name to the legend only once
                if not legend_added[model_name]:
                    plt.plot([], [], color=model_colors[model_name], label=model_name)
                    legend_added[model_name] = True

            # Run MixMHC for current fold and allele
            target_path_allele = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\model_output"
            mixmhc_scores = run_mixmhc(allele, fold, target_path_allele, peptide_length)

            # Calculate ROC curve for MixMHC
            fpr, tpr, _ = roc_curve(y_test, mixmhc_scores)
            roc_auc = auc(fpr, tpr)

            # Plot the ROC curve for MixMHC
            plt.plot(fpr, tpr, color=model_colors['mixmhc'], lw=2)

            # Add MixMHC to legend
            if not legend_added['mixmhc']:
                plt.plot([], [], color=model_colors['mixmhc'], label='MixMHC')
                legend_added['mixmhc'] = True

        # Final plot setup for the current allele and peptide length
        plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(f'ROC Curves for {allele} (Peptide Length: {peptide_length})')
        plt.legend(loc='lower right')
        plt.show()

# %%
# Load metrics
def load_metrics(file_path):
    with open(file_path, "r") as f:
        return json.load(f)

# %%
metrics_per_allele = {}
for file_path in files:
    metrics = load_metrics(file_path)
    for allele, folds in metrics.items():
        if allele not in metrics_per_allele:
            metrics_per_allele[allele] = {}

        for fold_data in folds:  # Check if folds is a list of dicts
            if not isinstance(fold_data, dict):  
                print(f"Unexpected format in {file_path} for allele {allele}: {type(fold_data)}")
                continue

            for metric, values in fold_data.items():
                if file_path == file_path_mhcpred and not metric.endswith("_mixmhc"):
                    continue  # Keep only _mixmhc metrics for file_path_mhcpred
                
                if metric not in metrics_per_allele[allele]:
                    metrics_per_allele[allele][metric] = []

                # Ensure values is a list
                if isinstance(values, list):
                    metrics_per_allele[allele][metric].extend(values)
                else:  # If it's a float or single value, wrap it in a list
                    metrics_per_allele[allele][metric].append(values)

# %%
metrics_per_allele
# Out:
# {'HLA-DRB101-01': {'accuracy': [0.7478260869565218,
#    0.7717391304347826,
#    0.7706521739130435,
#    0.7429347826086956,
#    0.7347826086956522,
#    0.7396739130434783,
#    0.7326086956521739,
#    0.7478260869565218,
#    0.75,
#    0.7438825448613376,
#    0.7432909604519774,
#    0.7387005649717514,
#    0.713276836158192,
#    0.7588276836158192,
#    0.7521186440677966,
#    0.7630649717514124,
#    0.7213983050847458,
#    0.7482344632768362,
#    0.7470858353938538,
#    0.7559166372306605,
#    0.6923913043478261,
#    0.6864130434782608,
#    0.6918478260869565,
#    0.6695652173913044,
#    0.6652173913043479,
#    0.6679347826086957,
#    0.6755434782608696,
#    0.6923913043478261,
#    0.6934782608695652,
#    0.6884176182707994,
#    0.7817796610169492,
#    0.7623587570621468,
#    0.7680084745762712,
#    0.7980225988700564,
#    0.7786016949152542,
#    0.7612994350282486,
#    0.763771186440678,
#    0.763771186440678,
#    0.7813493465206641,
#    0.7855881314023313],
#   'precision': [0.9174630755864466,
#    0.9286912751677853,
#    0.9153122326775022,
#    0.8976982097186701,
#    0.9133858267716536,
#    0.905790838375108,
#    0.903056768558952,
#    0.8949615713065756,
#    0.9072164948453608,
#    0.8966087675765095,
#    0.7247956403269755,
#    0.7375415282392026,
#    0.7219061166429588,
#    0.75,
#    0.7362491716368456,
#    0.7631763879128601,
#    0.7178619756427604,
#    0.7454050374404356,
#    0.7261987491313412,
#    0.7510373443983402,
#    0.9198435972629521,
#    0.9472595656670114,
#    0.9302083333333333,
#    0.933695652173913,
#    0.9331919406150583,
#    0.9419496166484118,
#    0.9416846652267818,
#    0.9354497354497354,
#    0.9368530020703933,
#    0.9422084623323014,
#    0.7829286239882266,
#    0.7896296296296297,
#    0.8113509192645884,
#    0.8010241404535479,
#    0.7966867469879518,
#    0.7664756446991404,
#    0.7952086553323029,
#    0.79265493496557,
#    0.7675250357653791,
#    0.7956204379562044],
#   'recall': [0.7410526315789474,
#    0.7676837725381415,
#    0.7681263460157932,
#    0.7489331436699858,
#    0.7285415212840195,
#    0.7390691114245416,
#    0.7307420494699647,
#    0.7544996400287977,
#    0.75,
#    0.7580419580419581,
#    0.7671232876712328,
#    0.7628865979381443,
#    0.7068245125348189,
#    0.7655913978494624,
#    0.7851590106007067,
#    0.7647887323943662,
#    0.7404047452896022,
#    0.7635983263598326,
#    0.7644476956839795,
#    0.766407904022583,
#    0.6603508771929825,
#    0.6352288488210819,
#    0.6410624551328069,
#    0.6109530583214794,
#    0.6140963014654571,
#    0.6064880112834978,
#    0.6162544169611307,
#    0.6364290856731462,
#    0.6427556818181818,
#    0.6384615384615384,
#    0.7671232876712328,
#    0.7326460481099656,
#    0.7068245125348189,
#    0.7849462365591398,
#    0.7477031802120141,
#    0.7535211267605634,
#    0.7180739706908583,
#    0.7224546722454672,
#    0.7849305047549379,
#    0.7692307692307693],
#   'f1_score': [0.8198757763975155,
#    0.8405466970387244,
#    0.8352849336455894,
#    0.8165955796820473,
#    0.8105590062111802,
#    0.8139805825242719,
#    0.8078125,
#    0.81875,
#    0.8211508553654744,
#    0.821523304281925,
#    0.7453590192644484,
#    0.75,
#    0.7142857142857143,
#    0.7577155019510464,
#    0.7599179206566348,
#    0.7639817094618361,
#    0.7289591205771213,
#    0.7543920082673097,
#    0.744832501781896,
#    0.7586447782046805,
#    0.7687908496732027,
#    0.7604815276048152,
#    0.7590310242243944,
#    0.7386070507308684,
#    0.7407407407407407,
#    0.7378807378807379,
#    0.7449807774455361,
#    0.7574978577549272,
#    0.7624262847514743,
#    0.7611504793664027,
#    0.7749453750910416,
#    0.7600713012477719,
#    0.7554893933755117,
#    0.7929036929761043,
#    0.7714181553044113,
#    0.7599431818181818,
#    0.7546754675467546,
#    0.7559284932506385,
#    0.776130198915009,
#    0.7822030857552924],
#   'auc': [0.8311824138659902,
#    0.8462074589312721,
#    0.8429539837249527,
#    0.8049578501615853,
#    0.8131032129636456,
#    0.8242192461179553,
#    0.7991585948867179,
#    0.8079844964952692,
#    0.824014066445707,
#    0.8009121685160805,
#    0.8202238781767425,
#    0.8192310091912545,
#    0.7903021765330313,
#    0.8361440974950303,
#    0.8394403146048363,
#    0.8439048597534213,
#    0.8009564203720433,
#    0.8338042192173318,
#    0.8231988599342024,
#    0.832682849896039,
#    0.8027588247727754,
#    0.8348660779626288,
#    0.8241527227058912,
#    0.8101544729303644,
#    0.7949354543911418,
#    0.8205711602350283,
#    0.8123234254832675,
#    0.818054112212043,
#    0.8096812855113635,
#    0.8245550293227555,
#    0.8547017161332491,
#    0.8403901104797271,
#    0.8448885993407347,
#    0.8756449492795374,
#    0.854026448152295,
#    0.8314652076766548,
#    0.8382001499426117,
#    0.8459674410345123,
#    0.8717885681621036,
#    0.8590004781302809],
#   'accuracy_mixmhc': [0.7849944008958567,
#    0.7827547592385219,
#    0.776595744680851,
#    0.7788353863381859,
#    0.7777155655095185,
#    0.7704367301231803,
#    0.7704367301231803,
#    0.7737961926091825,
#    0.7721164613661814,
#    0.773109243697479],
#   'precision_mixmhc': [0.8720059880239521,
#    0.8648449039881831,
#    0.8527422990232908,
#    0.8626126126126126,
#    0.8677563150074294,
#    0.8750963762528913,
#    0.8697318007662835,
#    0.8584269662921349,
#    0.849772382397572,
#    0.8607784431137725],
#   'recall_mixmhc': [0.8454281567489115,
#    0.8510174418604651,
#    0.8482810164424515,
#    0.8442321822189567,
#    0.8421052631578947,
#    0.8206796818510484,
#    0.8254545454545454,
#    0.8420279206465834,
#    0.8427389014296464,
#    0.8400292184075968],
#   'f1_score_mixmhc': [0.8585114222549742,
#    0.8578754578754578,
#    0.8505058074185088,
#    0.8533234311177126,
#    0.8547383827296011,
#    0.8470149253731343,
#    0.8470149253731343,
#    0.8501483679525222,
#    0.8462410275783906,
#    0.8502772643253235],
#   'auc_score_mixmhc': [0.8335876803551608,
#    0.8260236457742485,
#    0.8314940676382662,
#    0.839250551065393,
#    0.8228736946909451,
#    0.8228147892971908,
#    0.8291944260119443,
#    0.8218602238838225,
#    0.8278348835026748,
#    0.8317149660055065]},
#  'HLA-DRB103-01': {'accuracy': [0.8396946564885496,
#    0.8522447923405356,
#    0.8951998964937249,
#    0.8862724802691163,
#    0.8399534221762195,
#    0.8865312459567861,
#    0.8574201060939319,
#    0.8959627329192547,
#    0.8933747412008282,
#    0.8795289855072463,
#    0.8733660130718954,
#    0.8496732026143791,
#    0.8585445625511039,
#    0.8634505314799673,
#    0.8111201962387572,
#    0.8266557645134914,
#    0.856909239574816,
#    0.8421913327882257,
#    0.8544562551103843,
#    0.856909239574816,
#    0.9584681071289947,
#    0.9465648854961832,
#    0.957950575753655,
#    0.9483762453098719,
#    0.953939707594773,
#    0.9563979816276362,
#    0.9505757536550653,
#    0.9607919254658385,
#    0.9484989648033126,
#    0.9334886128364389,
#    0.8700980392156863,
#    0.8513071895424836,
#    0.874897792313982,
#    0.8773507767784138,
#    0.848732624693377,
#    0.8111201962387572,
#    0.8904333605887162,
#    0.8070318887980377,
#    0.8732624693376942,
#    0.8626328699918234],
#   'precision': [0.27700463883366466,
#    0.3385518590998043,
#    0.4106280193236715,
#    0.38497652582159625,
#    0.3187960687960688,
#    0.40364188163884673,
#    0.32745762711864407,
#    0.4180194805194805,
#    0.41825396825396827,
#    0.3981348637015782,
#    0.8667687595712098,
#    0.8500797448165869,
#    0.8276923076923077,
#    0.85625,
#    0.8084772370486656,
#    0.8273615635179153,
#    0.8427480916030534,
#    0.8184764991896273,
#    0.8300970873786407,
#    0.84185303514377,
#    0.6881720430107527,
#    0.6519480519480519,
#    0.697151424287856,
#    0.6363636363636364,
#    0.7001375515818432,
#    0.7048710601719198,
#    0.6522366522366523,
#    0.7296466973886329,
#    0.6558073654390935,
#    0.5792610250297974,
#    0.8938640132669984,
#    0.8668885191347754,
#    0.8631921824104235,
#    0.9215686274509803,
#    0.8512,
#    0.8123980424143556,
#    0.8951612903225806,
#    0.7859477124183006,
#    0.8841354723707665,
#    0.8606965174129353],
#   'recall': [0.7385159010600707,
#    0.8021638330757341,
#    0.8673469387755102,
#    0.841025641025641,
#    0.8021638330757341,
#    0.8539325842696629,
#    0.8145025295109612,
#    0.8554817275747508,
#    0.8527508090614887,
#    0.8578052550231839,
#    0.8927444794952681,
#    0.85553772070626,
#    0.8981636060100167,
#    0.8796147672552167,
#    0.8253205128205128,
#    0.8273615635179153,
#    0.8846153846153846,
#    0.8617747440273038,
#    0.8754266211604096,
#    0.8739635157545605,
#    0.7915194346289752,
#    0.7758887171561051,
#    0.7908163265306123,
#    0.7418803418803419,
#    0.7867078825347759,
#    0.7897271268057785,
#    0.7622259696458684,
#    0.7890365448504983,
#    0.7491909385113269,
#    0.7511591962905718,
#    0.8501577287066246,
#    0.8362760834670947,
#    0.8848080133555927,
#    0.8298555377207063,
#    0.8525641025641025,
#    0.8110749185667753,
#    0.8894230769230769,
#    0.8208191126279863,
#    0.8464163822525598,
#    0.8606965174129353],
#   'f1_score': [0.40289156626506023,
#    0.4761467889908257,
#    0.5573770491803278,
#    0.5281803542673108,
#    0.4562637362637363,
#    0.5481710458526533,
#    0.4671179883945841,
#    0.5616139585605234,
#    0.5612353567625133,
#    0.5438510534051936,
#    0.8795648795648796,
#    0.8528,
#    0.8614891913530824,
#    0.8677751385589866,
#    0.816812053925456,
#    0.8273615635179153,
#    0.8631743549648163,
#    0.8395677472984207,
#    0.8521594684385382,
#    0.8576078112286412,
#    0.7362366474938373,
#    0.7085391672547636,
#    0.7410358565737052,
#    0.6850828729281768,
#    0.7409024745269287,
#    0.744890234670704,
#    0.702954898911353,
#    0.7581803671189146,
#    0.6993957703927492,
#    0.6541049798115747,
#    0.8714632174616006,
#    0.8513071895424836,
#    0.8738664468260511,
#    0.8733108108108109,
#    0.8518815052041633,
#    0.8117359413202934,
#    0.8922829581993569,
#    0.8030050083472454,
#    0.8648648648648649,
#    0.8606965174129353],
#   'auc': [0.8772224165309658,
#    0.9136199617027647,
#    0.9494164911448405,
#    0.9435052784716838,
#    0.8985845649134645,
#    0.9458265323225147,
#    0.9109866888739326,
#    0.9451034674389698,
#    0.9530941196819285,
#    0.9420581930398237,
#    0.9367213815965354,
#    0.9252770262510582,
#    0.929802876589187,
#    0.9375093632958802,
#    0.9023452549120329,
#    0.8964073105373791,
#    0.9341209708488505,
#    0.9167197989723589,
#    0.9245342663187617,
#    0.9225592467768684,
#    0.9742885134591829,
#    0.9431333633344348,
#    0.9500740430607195,
#    0.9432549937309176,
#    0.9619626918408207,
#    0.9674161369294775,
#    0.9416952922360271,
#    0.9703539889021812,
#    0.937365554690736,
#    0.935622833771372,
#    0.942944982088435,
#    0.9241419464082067,
#    0.9504917383673643,
#    0.9271294810058855,
#    0.929556739865588,
#    0.9030209185774725,
#    0.9497185480073628,
#    0.8919047797643606,
#    0.9353920092584158,
#    0.9386428074680361],
#   'accuracy_mixmhc': [0.6984332513272045,
#    0.7093098536838016,
#    0.7041305192282792,
#    0.7034831024213388,
#    0.7029651689757866,
#    0.708015020069921,
#    0.693124433510294,
#    0.7103457205749061,
#    0.6999481999481999,
#    0.707977207977208],
#   'precision_mixmhc': [0.19071076706544687,
#    0.21557522123893805,
#    0.1985790408525755,
#    0.1963778409090909,
#    0.21274373259052926,
#    0.21048901488306165,
#    0.19190871369294607,
#    0.2042507204610951,
#    0.20396108408617095,
#    0.21774193548387097],
#   'recall_mixmhc': [0.9492119089316988,
#    0.9545454545454546,
#    0.9506802721088435,
#    0.9534482758620689,
#    0.9487577639751553,
#    0.9565217391304348,
#    0.9438775510204082,
#    0.9529411764705882,
#    0.9575856443719413,
#    0.9627906976744186],
#   'f1_score_mixmhc': [0.31760914151772635,
#    0.3517181634421022,
#    0.32853364678225094,
#    0.32567726737338043,
#    0.34755403868031853,
#    0.3450479233226837,
#    0.31896551724137934,
#    0.33639869474933254,
#    0.3362933256946434,
#    0.3551615670574778],
#   'auc_score_mixmhc': [0.9393950524414565,
#    0.9446634352676744,
#    0.9448618480328362,
#    0.9447953627134353,
#    0.9359003184118191,
#    0.9449639052935124,
#    0.9416751283554767,
#    0.94976421545049,
#    0.9462663301373142,
#    0.9454679587658676]},
#  'HLA-DRB107-01': {'accuracy': [0.8362350380848749,
#    0.8307943416757345,
#    0.8329706202393906,
#    0.7905331882480957,
#    0.8226332970620239,
#    0.8335146898803046,
#    0.8117519042437432,
#    0.8073993471164309,
#    0.7834602829162133,
#    0.8165487207403375,
#    0.8173138128580522,
#    0.8109484404837684,
#    0.8313176320814768,
#    0.7905792488860598,
#    0.8173138128580522,
#    0.803946530872056,
#    0.8058561425843411,
#    0.81031190324634,
#    0.8197452229299363,
#    0.8006369426751593,
#    0.8286180631120783,
#    0.8275299238302503,
#    0.8313384113166485,
#    0.8215451577801959,
#    0.823721436343852,
#    0.8269858541893362,
#    0.8193688792165397,
#    0.8280739934711643,
#    0.8204570184983678,
#    0.8149156232988568,
#    0.8446849140674729,
#    0.8472310630171865,
#    0.852959898154042,
#    0.8255887969446213,
#    0.8268618714194781,
#    0.8058561425843411,
#    0.8166772756206238,
#    0.8166772756206238,
#    0.8382165605095542,
#    0.8222929936305733],
#   'precision': [0.8031591737545565,
#    0.7914572864321608,
#    0.7913043478260869,
#    0.7337962962962963,
#    0.7750294464075382,
#    0.7927590511860175,
#    0.7737665463297232,
#    0.7514518002322881,
#    0.7199519230769231,
#    0.7852684144818977,
#    0.8133498145859085,
#    0.8017565872020075,
#    0.8107784431137725,
#    0.7751256281407035,
#    0.8063725490196079,
#    0.8048192771084337,
#    0.8037825059101655,
#    0.796895213454075,
#    0.799475753604194,
#    0.7929824561403509,
#    0.9061976549413735,
#    0.9003496503496503,
#    0.9175627240143369,
#    0.8913412563667232,
#    0.8914858096828047,
#    0.8727569331158238,
#    0.8954468802698144,
#    0.8866995073891626,
#    0.8780487804878049,
#    0.8834459459459459,
#    0.8489847715736041,
#    0.8674863387978142,
#    0.8576972833117723,
#    0.8409405255878285,
#    0.8366013071895425,
#    0.8055222088835534,
#    0.8314606741573034,
#    0.809775429326288,
#    0.8257372654155496,
#    0.8433889602053916],
#   'recall': [0.82625,
#    0.8129032258064516,
#    0.8208762886597938,
#    0.8035487959442332,
#    0.8297604035308953,
#    0.8193548387096774,
#    0.8027465667915106,
#    0.8221092757306226,
#    0.7840314136125655,
#    0.792191435768262,
#    0.8287153652392947,
#    0.8213367609254498,
#    0.8635204081632653,
#    0.8044328552803129,
#    0.8360864040660737,
#    0.8206388206388207,
#    0.8302808302808303,
#    0.8137384412153237,
#    0.8243243243243243,
#    0.8329238329238329,
#    0.67625,
#    0.6645161290322581,
#    0.6597938144329897,
#    0.6653992395437263,
#    0.6733921815889029,
#    0.6903225806451613,
#    0.6629213483146067,
#    0.6861499364675985,
#    0.6596858638743456,
#    0.6586901763224181,
#    0.8425692695214105,
#    0.8161953727506427,
#    0.8456632653061225,
#    0.7926988265971316,
#    0.8132147395171537,
#    0.8243243243243243,
#    0.8131868131868132,
#    0.809775429326288,
#    0.8324324324324325,
#    0.8071253071253072],
#   'f1_score': [0.8145409735058533,
#    0.8020369191597708,
#    0.8058191018342821,
#    0.7670901391409558,
#    0.8014616321559074,
#    0.8058375634517766,
#    0.7879901960784313,
#    0.7851941747572816,
#    0.7506265664160401,
#    0.7887147335423198,
#    0.8209606986899564,
#    0.8114285714285714,
#    0.8363187152563311,
#    0.7895073576455535,
#    0.8209606986899564,
#    0.8126520681265207,
#    0.8168168168168168,
#    0.8052287581699347,
#    0.8117099135063207,
#    0.8124625524266027,
#    0.7745168217609163,
#    0.7646622123236823,
#    0.767616191904048,
#    0.7619738751814223,
#    0.7672413793103449,
#    0.770893371757925,
#    0.7618364418938307,
#    0.7736389684813754,
#    0.7533632286995515,
#    0.7546897546897547,
#    0.8457648546144121,
#    0.8410596026490066,
#    0.8516377649325626,
#    0.8161073825503355,
#    0.8247422680412371,
#    0.8148148148148148,
#    0.8222222222222222,
#    0.809775429326288,
#    0.82907133243607,
#    0.8248587570621468],
#   'auc': [0.9150903179190752,
#    0.9032895335781266,
#    0.9060619187683228,
#    0.8693758676559606,
#    0.9080187284673912,
#    0.9034351955815859,
#    0.8923645346884379,
#    0.8995208774362651,
#    0.8590811372078738,
#    0.8953959586640938,
#    0.8961970246605007,
#    0.8953471409537826,
#    0.9112118481445944,
#    0.8674116380288908,
#    0.9023043461348963,
#    0.8963141717434979,
#    0.882191242563583,
#    0.9049688574127146,
#    0.9031569521328557,
#    0.8785945035945035,
#    0.899315992292871,
#    0.8852225897490364,
#    0.8920941571048595,
#    0.8820006016956217,
#    0.8939675509994751,
#    0.8836360877613569,
#    0.8731756471238339,
#    0.8876111212531903,
#    0.8785952109352912,
#    0.8799408797042053,
#    0.9260768505100999,
#    0.9308343895979279,
#    0.9250576977932214,
#    0.9084466844396012,
#    0.905497173456422,
#    0.887330046511024,
#    0.897318993063674,
#    0.9068740891726361,
#    0.9127271247150764,
#    0.9056556556556556],
#   'accuracy_mixmhc': [0.6473799126637555,
#    0.6588427947598253,
#    0.6610262008733624,
#    0.6653930131004366,
#    0.6517467248908297,
#    0.6577510917030568,
#    0.6610262008733624,
#    0.647187329328236,
#    0.6504642271982524,
#    0.6444565811032222],
#   'precision_mixmhc': [0.5529500756429652,
#    0.5651162790697675,
#    0.55390625,
#    0.5664873174481169,
#    0.5549698795180723,
#    0.5574402467232074,
#    0.5707656612529002,
#    0.5487336914811972,
#    0.5494163424124514,
#    0.552790346907994],
#   'recall_mixmhc': [0.9300254452926209,
#    0.9192938209331651,
#    0.9341238471673254,
#    0.9376590330788804,
#    0.9400510204081632,
#    0.9317010309278351,
#    0.917910447761194,
#    0.92496765847348,
#    0.9204693611473272,
#    0.9266750948166877],
#   'f1_score_mixmhc': [0.6935483870967742,
#    0.699951992318771,
#    0.6954389406571849,
#    0.7062769525634882,
#    0.6979166666666666,
#    0.6975397973950795,
#    0.703862660944206,
#    0.6888246628131022,
#    0.6881091617933723,
#    0.6924893717524799],
#   'auc_score_mixmhc': [0.8697345759198984,
#    0.8687796370309506,
#    0.8779019581118532,
#    0.8842403388164777,
#    0.88811718628291,
#    0.8867657323883161,
#    0.8763780804150454,
#    0.8664252158751042,
#    0.869484050739626,
#    0.8728198239813285]},
#  'HLA-DRB111-01': {'accuracy': [0.8492392807745505,
#    0.8160442600276625,
#    0.8284923928077456,
#    0.8063623789764869,
#    0.8215767634854771,
#    0.7856154910096819,
#    0.8298755186721992,
#    0.8105117565698479,
#    0.8243430152143845,
#    0.8229598893499308,
#    0.8547671840354767,
#    0.835920177383592,
#    0.8170731707317073,
#    0.8259423503325942,
#    0.8268590455049944,
#    0.8335183129855716,
#    0.8446170921198668,
#    0.8113207547169812,
#    0.8412874583795783,
#    0.8146503884572697,
#    0.8008298755186722,
#    0.8132780082987552,
#    0.7856154910096819,
#    0.8008298755186722,
#    0.7966804979253111,
#    0.8008298755186722,
#    0.8091286307053942,
#    0.7579529737206085,
#    0.7911479944674965,
#    0.8105117565698479,
#    0.8215077605321508,
#    0.8603104212860311,
#    0.8603104212860311,
#    0.8348115299334812,
#    0.8290788013318535,
#    0.8235294117647058,
#    0.8379578246392897,
#    0.8501664816870145,
#    0.8201997780244173,
#    0.8734739178690344],
#   'precision': [0.9151376146788991,
#    0.8823529411764706,
#    0.8866995073891626,
#    0.8672768878718535,
#    0.8812351543942993,
#    0.8293269230769231,
#    0.8848039215686274,
#    0.8826185101580135,
#    0.8717948717948718,
#    0.8845208845208845,
#    0.8343685300207039,
#    0.8259958071278826,
#    0.8012422360248447,
#    0.8319838056680162,
#    0.7895927601809954,
#    0.8084210526315789,
#    0.8226164079822617,
#    0.7987927565392354,
#    0.8496868475991649,
#    0.7765726681127982,
#    0.9407008086253369,
#    0.9549295774647887,
#    0.9125364431486881,
#    0.9272237196765498,
#    0.9220055710306406,
#    0.9203539823008849,
#    0.9283667621776505,
#    0.923943661971831,
#    0.90633608815427,
#    0.9153005464480874,
#    0.8233995584988962,
#    0.8917647058823529,
#    0.8819444444444444,
#    0.8544303797468354,
#    0.8193069306930693,
#    0.8333333333333334,
#    0.8352941176470589,
#    0.8807339449541285,
#    0.8434782608695652,
#    0.8615023474178404],
#   'recall': [0.8471337579617835,
#    0.8187772925764192,
#    0.821917808219178,
#    0.8221258134490239,
#    0.8244444444444444,
#    0.8041958041958042,
#    0.8260869565217391,
#    0.8214285714285714,
#    0.8385650224215246,
#    0.8163265306122449,
#    0.8876651982378855,
#    0.8583877995642701,
#    0.8486842105263158,
#    0.8474226804123711,
#    0.8470873786407767,
#    0.8668171557562077,
#    0.8607888631090487,
#    0.8501070663811563,
#    0.8514644351464435,
#    0.8483412322274881,
#    0.7409766454352441,
#    0.740174672489083,
#    0.7146118721461188,
#    0.7462039045553145,
#    0.7355555555555555,
#    0.7272727272727273,
#    0.7414187643020596,
#    0.6890756302521008,
#    0.7376681614349776,
#    0.7596371882086168,
#    0.8215859030837004,
#    0.8257080610021786,
#    0.8355263157894737,
#    0.8350515463917526,
#    0.8033980582524272,
#    0.801354401805869,
#    0.8236658932714617,
#    0.8222698072805139,
#    0.8117154811715481,
#    0.8696682464454977],
#   'f1_score': [0.8798235942668137,
#    0.8493771234428086,
#    0.8530805687203792,
#    0.844097995545657,
#    0.851894374282434,
#    0.8165680473372781,
#    0.8544378698224852,
#    0.8509249183895539,
#    0.8548571428571429,
#    0.8490566037735849,
#    0.8601921024546425,
#    0.8418803418803419,
#    0.8242811501597445,
#    0.839632277834525,
#    0.8173302107728337,
#    0.8366013071895425,
#    0.8412698412698413,
#    0.8236514522821576,
#    0.8505747126436781,
#    0.8108720271800679,
#    0.828978622327791,
#    0.8339483394833949,
#    0.8015364916773368,
#    0.8269230769230769,
#    0.8182941903584673,
#    0.8125,
#    0.8244274809160306,
#    0.789410348977136,
#    0.8133498145859085,
#    0.8302354399008675,
#    0.8224917309812569,
#    0.8574660633484162,
#    0.8581081081081081,
#    0.8446298227320125,
#    0.8112745098039216,
#    0.8170310701956272,
#    0.8294392523364486,
#    0.8504983388704319,
#    0.8272921108742004,
#    0.8655660377358491],
#   'auc': [0.9131702220874196,
#    0.9026448051413034,
#    0.8971361051029402,
#    0.8865435246973887,
#    0.8975905575905576,
#    0.8808572380000951,
#    0.8852714790929894,
#    0.8823274248970844,
#    0.8936960709718151,
#    0.8912770782071695,
#    0.9281977658904972,
#    0.9156031612544691,
#    0.9014387144992526,
#    0.9120670473930135,
#    0.9131623880715548,
#    0.9215304543259043,
#    0.9253443254183739,
#    0.9008279142284806,
#    0.9177769864585497,
#    0.896456875995607,
#    0.9021416776193845,
#    0.9037653456373074,
#    0.8778939357526234,
#    0.8921072676392177,
#    0.8838420838420837,
#    0.8898006755149612,
#    0.884943431854187,
#    0.8589545129792808,
#    0.8751841479011186,
#    0.8933195027419951,
#    0.9035114458779107,
#    0.9313848438798645,
#    0.938281803162615,
#    0.9296051818339143,
#    0.9083526912462524,
#    0.9109190020404743,
#    0.9213407710914745,
#    0.922478019321288,
#    0.9027320296349051,
#    0.9440975966913693],
#   'accuracy_mixmhc': [0.7755960729312763,
#    0.7321178120617111,
#    0.7545582047685835,
#    0.7671809256661991,
#    0.7556179775280899,
#    0.7907303370786517,
#    0.7612359550561798,
#    0.7949438202247191,
#    0.7528089887640449,
#    0.7696629213483146],
#   'precision_mixmhc': [0.7658450704225352,
#    0.7180385288966725,
#    0.7410071942446043,
#    0.7539543057996485,
#    0.736936936936937,
#    0.759493670886076,
#    0.7333333333333333,
#    0.7864768683274022,
#    0.7329842931937173,
#    0.7435897435897436],
#   'recall_mixmhc': [0.9415584415584416,
#    0.9318181818181818,
#    0.9300225733634312,
#    0.9428571428571428,
#    0.9359267734553776,
#    0.963302752293578,
#    0.9487179487179487,
#    0.9444444444444444,
#    0.9480812641083521,
#    0.9441860465116279],
#   'f1_score_mixmhc': [0.8446601941747572,
#    0.811078140454995,
#    0.8248248248248248,
#    0.837890625,
#    0.8245967741935484,
#    0.8493427704752275,
#    0.8272357723577236,
#    0.858252427184466,
#    0.8267716535433071,
#    0.8319672131147541],
#   'auc_score_mixmhc': [0.9105396595436437,
#    0.8834748584748584,
#    0.9018852938717498,
#    0.8991949910554562,
#    0.8923361764094029,
#    0.9195253290785799,
#    0.910688840017462,
#    0.9137636612021858,
#    0.9082296273297137,
#    0.9145101434933202]},
#  'HLA-DRB112-01': {'accuracy': [0.8449197860962567,
#    0.8823529411764706,
#    0.8716577540106952,
#    0.9037433155080213,
#    0.8850267379679144,
#    0.8796791443850267,
#    0.8903743315508021,
#    0.8529411764705882,
#    0.8663101604278075,
#    0.8823529411764706,
#    0.8240917782026769,
#    0.8814531548757171,
#    0.875717017208413,
#    0.869980879541109,
#    0.8432122370936902,
#    0.8776290630975143,
#    0.8967495219885278,
#    0.8336520076481836,
#    0.8661567877629063,
#    0.8604206500956023,
#    0.8636363636363636,
#    0.9064171122994652,
#    0.8663101604278075,
#    0.9197860962566845,
#    0.9117647058823529,
#    0.9251336898395722,
#    0.9037433155080213,
#    0.8770053475935828,
#    0.8689839572192514,
#    0.8957219251336899,
#    0.8565965583173997,
#    0.8413001912045889,
#    0.8967495219885278,
#    0.8355640535372849,
#    0.8738049713193117,
#    0.8795411089866156,
#    0.8451242829827916,
#    0.8413001912045889,
#    0.8451242829827916,
#    0.8164435946462715],
#   'precision': [0.9098039215686274,
#    0.9404761904761905,
#    0.9590163934426229,
#    0.9357429718875502,
#    0.9450980392156862,
#    0.9322709163346613,
#    0.9421487603305785,
#    0.9288537549407114,
#    0.9079497907949791,
#    0.9196787148594378,
#    0.8035714285714286,
#    0.9077490774907749,
#    0.851985559566787,
#    0.8736059479553904,
#    0.8071428571428572,
#    0.8571428571428571,
#    0.8936170212765957,
#    0.8216783216783217,
#    0.8237410071942446,
#    0.8255813953488372,
#    0.9736842105263158,
#    0.9676113360323887,
#    0.9868421052631579,
#    0.9626556016597511,
#    0.9836734693877551,
#    0.9717741935483871,
#    0.9659574468085106,
#    0.9829059829059829,
#    0.9579439252336449,
#    0.9495798319327731,
#    0.8303886925795053,
#    0.8846153846153846,
#    0.8961538461538462,
#    0.8351648351648352,
#    0.8560606060606061,
#    0.86328125,
#    0.862453531598513,
#    0.8381294964028777,
#    0.8188679245283019,
#    0.7843137254901961],
#   'recall': [0.8689138576779026,
#    0.8909774436090225,
#    0.8602941176470589,
#    0.9209486166007905,
#    0.8925925925925926,
#    0.8931297709923665,
#    0.8941176470588236,
#    0.8639705882352942,
#    0.8857142857142857,
#    0.9051383399209486,
#    0.8587786259541985,
#    0.8692579505300353,
#    0.9076923076923077,
#    0.8736059479553904,
#    0.889763779527559,
#    0.891566265060241,
#    0.9130434782608695,
#    0.8671586715867159,
#    0.916,
#    0.8838174273858921,
#    0.8314606741573034,
#    0.8984962406015038,
#    0.8272058823529411,
#    0.9169960474308301,
#    0.8925925925925926,
#    0.9198473282442748,
#    0.8901960784313725,
#    0.8455882352941176,
#    0.8367346938775511,
#    0.8932806324110671,
#    0.8969465648854962,
#    0.8127208480565371,
#    0.8961538461538462,
#    0.8475836431226765,
#    0.889763779527559,
#    0.8875502008032129,
#    0.8405797101449275,
#    0.8597785977859779,
#    0.868,
#    0.8298755186721992],
#   'f1_score': [0.8888888888888888,
#    0.915057915057915,
#    0.9069767441860465,
#    0.9282868525896414,
#    0.9180952380952381,
#    0.9122807017543859,
#    0.9175050301810865,
#    0.8952380952380953,
#    0.8966942148760331,
#    0.9123505976095617,
#    0.8302583025830258,
#    0.8880866425992779,
#    0.8789571694599627,
#    0.8736059479553904,
#    0.846441947565543,
#    0.8740157480314961,
#    0.9032258064516129,
#    0.8438061041292639,
#    0.8674242424242424,
#    0.8537074148296593,
#    0.896969696969697,
#    0.9317738791423001,
#    0.9,
#    0.9392712550607287,
#    0.9359223300970874,
#    0.9450980392156862,
#    0.926530612244898,
#    0.9090909090909091,
#    0.8932461873638344,
#    0.9205702647657841,
#    0.8623853211009175,
#    0.8471454880294659,
#    0.8961538461538462,
#    0.8413284132841329,
#    0.8725868725868726,
#    0.8752475247524752,
#    0.8513761467889909,
#    0.848816029143898,
#    0.8427184466019417,
#    0.8064516129032258],
#   'auc': [0.9165529069970947,
#    0.9428780284043442,
#    0.9457720588235293,
#    0.9656028484630712,
#    0.9484330484330484,
#    0.9408056161395856,
#    0.9460537156038885,
#    0.9363465974625145,
#    0.9349153614934346,
#    0.9349949367915592,
#    0.9126524523997543,
#    0.9519581861012957,
#    0.9398069610997367,
#    0.944062289611568,
#    0.9273775722272634,
#    0.9517046287339138,
#    0.9581939799331104,
#    0.9165788086452293,
#    0.9507838827838827,
#    0.9327418263147054,
#    0.9338443767720256,
#    0.9684976329713173,
#    0.9405096597462514,
#    0.9728546695848169,
#    0.9706552706552707,
#    0.9673868593238822,
#    0.9534025374855825,
#    0.9664431949250288,
#    0.948046195222275,
#    0.9472119687714371,
#    0.9310929776841859,
#    0.9117196702002356,
#    0.9602222872184849,
#    0.9333196733307965,
#    0.9485993618827386,
#    0.9539178612259256,
#    0.9196884351346594,
#    0.9196684823991097,
#    0.919032967032967,
#    0.909670109767223],
#   'accuracy_mixmhc': [0.8172043010752689,
#    0.8091397849462365,
#    0.8279569892473119,
#    0.8172043010752689,
#    0.793010752688172,
#    0.8333333333333334,
#    0.7903225806451613,
#    0.8333333333333334,
#    0.7741935483870968,
#    0.8145161290322581],
#   'precision_mixmhc': [0.8158730158730159,
#    0.7955271565495208,
#    0.8121019108280255,
#    0.8163934426229508,
#    0.8032258064516129,
#    0.8360128617363344,
#    0.7760252365930599,
#    0.8387096774193549,
#    0.7580645161290323,
#    0.7953795379537953],
#   'recall_mixmhc': [0.9625468164794008,
#    0.97265625,
#    0.9807692307692307,
#    0.9540229885057471,
#    0.939622641509434,
#    0.959409594095941,
#    0.9723320158102767,
#    0.9558823529411765,
#    0.9631147540983607,
#    0.9717741935483871],
#   'f1_score_mixmhc': [0.8831615120274914,
#    0.875219683655536,
#    0.8885017421602788,
#    0.8798586572438163,
#    0.8660869565217392,
#    0.8934707903780069,
#    0.8631578947368421,
#    0.8934707903780069,
#    0.8483754512635379,
#    0.8747731397459165],
#   'auc_score_mixmhc': [0.9304084180488675,
#    0.939099542025862,
#    0.9330872252747253,
#    0.9395775085430257,
#    0.9110209839534474,
#    0.9403565817836397,
#    0.945361543827017,
#    0.9464338235294117,
#    0.9188812756147541,
#    0.9563930801248699]},
#  'HLA-DRB115-01': {'accuracy': [0.8111896080218779,
#    0.7923883318140383,
#    0.781563354603464,
#    0.784070191431176,
#    0.811965811965812,
#    0.8115099715099715,
#    0.8059259259259259,
#    0.7621652421652422,
#    0.7935042735042735,
#    0.7890598290598291,
#    0.7848396501457726,
#    0.7778425655976676,
#    0.7842565597667639,
#    0.7626822157434402,
#    0.7679300291545189,
#    0.7737609329446065,
#    0.7720116618075802,
#    0.797667638483965,
#    0.7854227405247813,
#    0.7924198250728863,
#    0.9251367365542388,
#    0.9136280765724704,
#    0.9205788514129444,
#    0.9291248860528715,
#    0.9251282051282051,
#    0.9307122507122507,
#    0.9296866096866097,
#    0.9264957264957265,
#    0.9253561253561253,
#    0.9223931623931624,
#    0.8052478134110788,
#    0.79533527696793,
#    0.7825072886297376,
#    0.8192419825072886,
#    0.7982507288629738,
#    0.7941690962099125,
#    0.7825072886297376,
#    0.8204081632653061,
#    0.8058309037900875,
#    0.8011661807580175],
#   'precision': [0.31701738334858187,
#    0.27933958054439983,
#    0.27615062761506276,
#    0.27060854553301683,
#    0.3177011494252874,
#    0.31664348632359757,
#    0.3101555352241537,
#    0.2506952721493842,
#    0.29760348583877994,
#    0.298007630351844,
#    0.7889908256880734,
#    0.7749419953596288,
#    0.7853932584269663,
#    0.75,
#    0.7520184544405998,
#    0.7737704918032787,
#    0.7587336244541485,
#    0.7847533632286996,
#    0.7627118644067796,
#    0.7926008968609866,
#    0.5992063492063492,
#    0.535953978906999,
#    0.5681818181818182,
#    0.6064908722109533,
#    0.5968992248062015,
#    0.633788037775446,
#    0.6385281385281385,
#    0.5930348258706468,
#    0.6108949416342413,
#    0.6014967259120674,
#    0.8266666666666667,
#    0.8181818181818182,
#    0.8121137206427689,
#    0.8381795195954488,
#    0.7900355871886121,
#    0.7991071428571429,
#    0.7956730769230769,
#    0.8405977584059776,
#    0.7927590511860175,
#    0.8096885813148789],
#   'recall': [0.808634772462077,
#    0.751500600240096,
#    0.7792207792207793,
#    0.7536057692307693,
#    0.8063010501750292,
#    0.7914252607184241,
#    0.7766323024054983,
#    0.7584134615384616,
#    0.7734994337485843,
#    0.7828507795100222,
#    0.7880870561282932,
#    0.7812865497076024,
#    0.7961275626423691,
#    0.7775147928994083,
#    0.7808383233532934,
#    0.796400449943757,
#    0.8034682080924855,
#    0.8187134502923976,
#    0.7855361596009975,
#    0.8052391799544419,
#    0.704784130688448,
#    0.6710684273709484,
#    0.7378984651711924,
#    0.71875,
#    0.7187864644107351,
#    0.6998841251448435,
#    0.6758304696449027,
#    0.7163461538461539,
#    0.711211778029445,
#    0.7160356347438753,
#    0.7812142038946163,
#    0.7578947368421053,
#    0.7482915717539863,
#    0.7846153846153846,
#    0.7976047904191617,
#    0.8053993250843644,
#    0.7653179190751445,
#    0.7894736842105263,
#    0.7917705735660848,
#    0.7995444191343963],
#   'f1_score': [0.4554715741045021,
#    0.4072869225764476,
#    0.4077849860982391,
#    0.3982216576691013,
#    0.4558047493403694,
#    0.452317880794702,
#    0.44328211833932657,
#    0.3768289041504927,
#    0.4298300818124607,
#    0.4316856002456248,
#    0.788538681948424,
#    0.7781013395457193,
#    0.7907239819004525,
#    0.7635095874491574,
#    0.7661574618096357,
#    0.7849223946784922,
#    0.7804604154969118,
#    0.8013737836290784,
#    0.773955773955774,
#    0.7988700564971751,
#    0.6477211796246649,
#    0.5959488272921108,
#    0.6420133538777607,
#    0.6578657865786579,
#    0.652196929592377,
#    0.6651982378854625,
#    0.6566499721758486,
#    0.6488840500816548,
#    0.6572475143903715,
#    0.6537874936451449,
#    0.8032979976442874,
#    0.7868852459016393,
#    0.7788974510966212,
#    0.8105134474327629,
#    0.7938021454112039,
#    0.8022408963585435,
#    0.7802003535651149,
#    0.8142340168878166,
#    0.7922645040548971,
#    0.8045845272206303],
#   'auc': [0.8950350271999915,
#    0.863838749650685,
#    0.8684463932632336,
#    0.8541108371581844,
#    0.8909848408261695,
#    0.8841686418506234,
#    0.8777076750328987,
#    0.8423291190114179,
#    0.8700491746160943,
#    0.8720675598914603,
#    0.863721080828116,
#    0.8577927376580987,
#    0.8718304607789509,
#    0.8466734679997279,
#    0.8511404463799673,
#    0.8525017907870476,
#    0.8609466167970078,
#    0.877439140486876,
#    0.866456531180264,
#    0.8774000321138244,
#    0.9319689304617654,
#    0.916240775549802,
#    0.9298816846025597,
#    0.9357925853571151,
#    0.9314067499925579,
#    0.9381838696109112,
#    0.9261045168723507,
#    0.9284189211109928,
#    0.9362850922332578,
#    0.9364427685915947,
#    0.8832989146552827,
#    0.8844757241942064,
#    0.8725965659979916,
#    0.8917907909950351,
#    0.8731192161132281,
#    0.8857259973253948,
#    0.874031961917715,
#    0.898139534883721,
#    0.8899137697923865,
#    0.8858979487975005],
#   'accuracy_mixmhc': [0.6550068587105624,
#    0.6697530864197531,
#    0.6483767718335619,
#    0.6439186099679927,
#    0.6558070416095108,
#    0.6576360310928212,
#    0.6502057613168725,
#    0.654320987654321,
#    0.6498227963873328,
#    0.6531382188178804],
#   'precision_mixmhc': [0.19939410630680254,
#    0.20171184022824537,
#    0.1948439620081411,
#    0.18881685575364668,
#    0.1997241379310345,
#    0.20318069646284617,
#    0.19776017481562413,
#    0.1979792463134899,
#    0.20445996775926922,
#    0.2096469954190245],
#   'recall_mixmhc': [0.8670658682634731,
#    0.8859649122807017,
#    0.8681983071342201,
#    0.8618988902589396,
#    0.86810551558753,
#    0.8927710843373494,
#    0.8547815820543093,
#    0.8928571428571429,
#    0.8818076477404403,
#    0.8850967007963595],
#   'f1_score_mixmhc': [0.32422749664128975,
#    0.3286079479432954,
#    0.3182624113475177,
#    0.3097717704409484,
#    0.3247364880017941,
#    0.3310252401161492,
#    0.321206743566992,
#    0.32409476978095664,
#    0.33195201744820063,
#    0.3389978213507625],
#   'auc_score_mixmhc': [0.8639857401335329,
#    0.8791195756687317,
#    0.8624930102537651,
#    0.8596789576111633,
#    0.8654251731291236,
#    0.8702327623198021,
#    0.8563303376330496,
#    0.878474299941403,
#    0.8677301903087233,
#    0.8646143304223902]},
#  'HLA-DRB301-01': {'accuracy': [0.8952991452991453,
#    0.8504273504273504,
#    0.8888888888888888,
#    0.8803418803418803,
#    0.892933618843683,
#    0.8715203426124197,
#    0.8843683083511777,
#    0.8351177730192719,
#    0.815845824411135,
#    0.8779443254817987,
#    0.8978102189781022,
#    0.8941605839416058,
#    0.8394160583941606,
#    0.8813868613138686,
#    0.9014598540145985,
#    0.8832116788321168,
#    0.8777372262773723,
#    0.8503649635036497,
#    0.8884826325411335,
#    0.8244972577696527,
#    0.8717948717948718,
#    0.8568376068376068,
#    0.8782051282051282,
#    0.8739316239316239,
#    0.8650963597430407,
#    0.9122055674518201,
#    0.8650963597430407,
#    0.8972162740899358,
#    0.8522483940042827,
#    0.8993576017130621,
#    0.9215328467153284,
#    0.8613138686131386,
#    0.885036496350365,
#    0.8540145985401459,
#    0.8667883211678832,
#    0.9124087591240876,
#    0.9142335766423357,
#    0.8503649635036497,
#    0.8756855575868373,
#    0.9159049360146252],
#   'precision': [0.9288389513108615,
#    0.8909090909090909,
#    0.910394265232975,
#    0.9182879377431906,
#    0.8961937716262975,
#    0.898876404494382,
#    0.9100719424460432,
#    0.8385826771653543,
#    0.8689138576779026,
#    0.900398406374502,
#    0.8768115942028986,
#    0.9103448275862069,
#    0.8661971830985915,
#    0.8913857677902621,
#    0.8836363636363637,
#    0.8576388888888888,
#    0.8901515151515151,
#    0.864963503649635,
#    0.8854961832061069,
#    0.8225806451612904,
#    0.9541666666666667,
#    0.9325396825396826,
#    0.948,
#    0.9774774774774775,
#    0.9354838709677419,
#    0.964,
#    0.9397590361445783,
#    0.9427312775330396,
#    0.9458333333333333,
#    0.948936170212766,
#    0.9201520912547528,
#    0.8767123287671232,
#    0.8949152542372881,
#    0.8849206349206349,
#    0.875,
#    0.8964285714285715,
#    0.9185185185185185,
#    0.9,
#    0.9012345679012346,
#    0.9338842975206612],
#   'recall': [0.8920863309352518,
#    0.8596491228070176,
#    0.9039145907473309,
#    0.8708487084870848,
#    0.9283154121863799,
#    0.8791208791208791,
#    0.8971631205673759,
#    0.8554216867469879,
#    0.8197879858657244,
#    0.875968992248062,
#    0.9166666666666666,
#    0.8918918918918919,
#    0.831081081081081,
#    0.8686131386861314,
#    0.9169811320754717,
#    0.9148148148148149,
#    0.8608058608058609,
#    0.8404255319148937,
#    0.8821292775665399,
#    0.796875,
#    0.8237410071942446,
#    0.8245614035087719,
#    0.8434163701067615,
#    0.8007380073800738,
#    0.8315412186379928,
#    0.8827838827838828,
#    0.8297872340425532,
#    0.8594377510040161,
#    0.8021201413427562,
#    0.8643410852713178,
#    0.9166666666666666,
#    0.8648648648648649,
#    0.8918918918918919,
#    0.8138686131386861,
#    0.8452830188679246,
#    0.9296296296296296,
#    0.9084249084249084,
#    0.7978723404255319,
#    0.8326996197718631,
#    0.8828125],
#   'f1_score': [0.9100917431192661,
#    0.875,
#    0.9071428571428571,
#    0.8939393939393939,
#    0.9119718309859155,
#    0.8888888888888888,
#    0.9035714285714286,
#    0.8469184890656064,
#    0.8436363636363636,
#    0.888015717092338,
#    0.8962962962962963,
#    0.9010238907849829,
#    0.8482758620689655,
#    0.8798521256931608,
#    0.9,
#    0.8853046594982079,
#    0.8752327746741154,
#    0.8525179856115108,
#    0.8838095238095238,
#    0.8095238095238095,
#    0.8841698841698842,
#    0.8752327746741154,
#    0.8926553672316384,
#    0.8803245436105477,
#    0.8804554079696395,
#    0.9216061185468452,
#    0.8813559322033898,
#    0.8991596638655462,
#    0.8680688336520076,
#    0.9046653144016227,
#    0.9184060721062619,
#    0.8707482993197279,
#    0.8934010152284264,
#    0.8479087452471483,
#    0.8598848368522073,
#    0.9127272727272727,
#    0.9134438305709024,
#    0.8458646616541353,
#    0.8656126482213439,
#    0.9076305220883534],
#   'auc': [0.9614539946989777,
#    0.931090020132298,
#    0.953793746550707,
#    0.9451364564407065,
#    0.960401891252955,
#    0.9385597220648767,
#    0.9328541307264712,
#    0.9152573597140856,
#    0.8944346289752649,
#    0.9331070805979007,
#    0.954518779342723,
#    0.9554375804375803,
#    0.9211845774345774,
#    0.961439075070595,
#    0.9685979065271019,
#    0.957300826005862,
#    0.9177222777222777,
#    0.9201861035567642,
#    0.951132651421839,
#    0.8946923324742266,
#    0.9506626277925029,
#    0.9270060396893874,
#    0.9480274801606181,
#    0.9395171109071496,
#    0.9406314344543583,
#    0.9536460103470413,
#    0.9395629672225417,
#    0.953391547842747,
#    0.9271777538792442,
#    0.9399317532732465,
#    0.9737115877080667,
#    0.9425541613041613,
#    0.9531451093951093,
#    0.9209867334434441,
#    0.9344756317087805,
#    0.9660005329070078,
#    0.9663936063936063,
#    0.9094544872820348,
#    0.9219996786804477,
#    0.9605213702749141],
#   'accuracy_mixmhc': [0.7317596566523605,
#    0.759656652360515,
#    0.7725321888412017,
#    0.7682403433476395,
#    0.7424892703862661,
#    0.759656652360515,
#    0.7532188841201717,
#    0.6946236559139785,
#    0.7677419354838709,
#    0.7053763440860215],
#   'precision_mixmhc': [0.6977329974811083,
#    0.720626631853786,
#    0.7306666666666667,
#    0.7295081967213115,
#    0.7016129032258065,
#    0.718421052631579,
#    0.7184986595174263,
#    0.6411609498680739,
#    0.7344173441734417,
#    0.654054054054054],
#   'recall_mixmhc': [0.9822695035460993,
#    0.9822064056939501,
#    0.982078853046595,
#    0.967391304347826,
#    0.9666666666666667,
#    0.9820143884892086,
#    0.9640287769784173,
#    0.9759036144578314,
#    0.9644128113879004,
#    0.9641434262948207],
#   'f1_score_mixmhc': [0.8159057437407953,
#    0.8313253012048193,
#    0.8379204892966361,
#    0.8317757009345794,
#    0.8130841121495327,
#    0.8297872340425532,
#    0.8233486943164362,
#    0.7738853503184714,
#    0.8338461538461538,
#    0.7793880837359098],
#   'auc_score_mixmhc': [0.9463845205057047,
#    0.9539674906222948,
#    0.9452877925363695,
#    0.9461098398169338,
#    0.9476379440665156,
#    0.9442350375019133,
#    0.9444837746823818,
#    0.9372582924289751,
#    0.9294542008355253,
#    0.9392616450087501]},
#  'HLA-DRB302-02': {'accuracy': [0.9173387096774194,
#    0.8649193548387096,
#    0.905241935483871,
#    0.8891129032258065,
#    0.8689516129032258,
#    0.9012096774193549,
#    0.907258064516129,
#    0.9032258064516129,
#    0.9133064516129032,
#    0.9254032258064516,
#    0.8850574712643678,
#    0.929757343550447,
#    0.9003831417624522,
#    0.896551724137931,
#    0.9104859335038363,
#    0.9028132992327366,
#    0.9271099744245525,
#    0.8887468030690537,
#    0.9117647058823529,
#    0.8797953964194374,
#    0.9193548387096774,
#    0.9193548387096774,
#    0.9193548387096774,
#    0.9173387096774194,
#    0.9213709677419355,
#    0.9455645161290323,
#    0.9455645161290323,
#    0.9112903225806451,
#    0.905241935483871,
#    0.9153225806451613,
#    0.876117496807152,
#    0.933588761174968,
#    0.913154533844189,
#    0.89272030651341,
#    0.8836317135549873,
#    0.9309462915601023,
#    0.8823529411764706,
#    0.921994884910486,
#    0.9143222506393862,
#    0.8913043478260869],
#   'precision': [0.9680851063829787,
#    0.9478021978021978,
#    0.967479674796748,
#    0.9667590027700831,
#    0.9427792915531336,
#    0.9572192513368984,
#    0.9671232876712329,
#    0.9803370786516854,
#    0.967741935483871,
#    0.9708994708994709,
#    0.8700980392156863,
#    0.9168765743073047,
#    0.8975,
#    0.8710462287104623,
#    0.8832116788321168,
#    0.8848920863309353,
#    0.8943488943488943,
#    0.8857808857808858,
#    0.8994974874371859,
#    0.8708860759493671,
#    0.9943977591036415,
#    0.9971830985915493,
#    0.9835164835164835,
#    0.9915966386554622,
#    0.9834710743801653,
#    0.9918918918918919,
#    0.9972375690607734,
#    0.9887005649717514,
#    0.9886363636363636,
#    0.9888579387186629,
#    0.8912466843501327,
#    0.9441489361702128,
#    0.9205128205128205,
#    0.8813131313131313,
#    0.8972972972972973,
#    0.9386189258312021,
#    0.8885869565217391,
#    0.9239904988123515,
#    0.9166666666666666,
#    0.901595744680851],
#   'recall': [0.926208651399491,
#    0.8778625954198473,
#    0.9107142857142857,
#    0.8903061224489796,
#    0.8871794871794871,
#    0.9156010230179028,
#    0.9121447028423773,
#    0.8948717948717949,
#    0.9207161125319693,
#    0.9338422391857506,
#    0.9056122448979592,
#    0.9430051813471503,
#    0.9065656565656566,
#    0.927461139896373,
#    0.9428571428571428,
#    0.929471032745592,
#    0.9629629629629629,
#    0.9090909090909091,
#    0.9250645994832042,
#    0.8888888888888888,
#    0.9033078880407125,
#    0.9007633587786259,
#    0.9132653061224489,
#    0.9030612244897959,
#    0.9153846153846154,
#    0.9386189258312021,
#    0.9328165374677002,
#    0.8974358974358975,
#    0.8900255754475703,
#    0.9033078880407125,
#    0.8571428571428571,
#    0.9196891191709845,
#    0.9065656565656566,
#    0.9041450777202072,
#    0.8623376623376623,
#    0.924433249370277,
#    0.8650793650793651,
#    0.930622009569378,
#    0.9095607235142119,
#    0.875968992248062],
#   'f1_score': [0.9466840052015605,
#    0.9114927344782034,
#    0.938239159001314,
#    0.9269588313413014,
#    0.9141347424042272,
#    0.9359477124183007,
#    0.9388297872340425,
#    0.935656836461126,
#    0.9436435124508519,
#    0.9520103761348897,
#    0.8875,
#    0.929757343550447,
#    0.9020100502512562,
#    0.8983688833124216,
#    0.9120603015075377,
#    0.9066339066339066,
#    0.9273885350318471,
#    0.89728453364817,
#    0.9121019108280255,
#    0.8797953964194374,
#    0.9466666666666667,
#    0.946524064171123,
#    0.9470899470899471,
#    0.945260347129506,
#    0.9482071713147411,
#    0.9645203679369251,
#    0.9639519359145527,
#    0.9408602150537635,
#    0.9367429340511441,
#    0.9441489361702128,
#    0.8738621586475943,
#    0.931758530183727,
#    0.9134860050890585,
#    0.8925831202046036,
#    0.8794701986754967,
#    0.9314720812182741,
#    0.8766756032171582,
#    0.9272943980929678,
#    0.9130998702983139,
#    0.8885976408912188],
#   'auc': [0.9671681612688062,
#    0.9420193186590577,
#    0.9575402276295133,
#    0.9527815934065934,
#    0.9412675374939525,
#    0.9487516745828767,
#    0.9590356304672498,
#    0.9613449443638123,
#    0.9664596273291927,
#    0.9655870945428494,
#    0.9559345477321363,
#    0.9768536041033137,
#    0.9644572338370788,
#    0.9616097414546925,
#    0.9727697994700514,
#    0.9650037619810918,
#    0.9736955838440987,
#    0.9454624323045375,
#    0.9644065024694991,
#    0.9433159977758152,
#    0.9817930284839052,
#    0.9814471701376023,
#    0.9758388932496076,
#    0.9713255494505496,
#    0.9728350266086115,
#    0.9822433321154548,
#    0.9825522129767916,
#    0.9702467343976778,
#    0.9687248812568505,
#    0.9794461325625634,
#    0.9347434626024324,
#    0.9741258923793737,
#    0.9642223266254274,
#    0.9595215410918678,
#    0.9543328208315613,
#    0.9750597010042854,
#    0.9446016030174446,
#    0.9762342920237657,
#    0.9744480423903444,
#    0.9448205933339875],
#   'accuracy_mixmhc': [0.8707070707070707,
#    0.8707070707070707,
#    0.8808080808080808,
#    0.8686868686868687,
#    0.8121212121212121,
#    0.8747474747474747,
#    0.8323232323232324,
#    0.8383838383838383,
#    0.8383838383838383,
#    0.8646464646464647],
#   'precision_mixmhc': [0.8698630136986302,
#    0.8791946308724832,
#    0.8888888888888888,
#    0.8755868544600939,
#    0.823394495412844,
#    0.8784403669724771,
#    0.8377777777777777,
#    0.8515981735159818,
#    0.8571428571428571,
#    0.8671171171171171],
#   'recall_mixmhc': [0.9819587628865979,
#    0.9751861042183623,
#    0.9751243781094527,
#    0.9688311688311688,
#    0.9573333333333334,
#    0.9770408163265306,
#    0.9741602067183462,
#    0.961340206185567,
#    0.9538461538461539,
#    0.9796437659033079],
#   'f1_score_mixmhc': [0.9225181598062954,
#    0.9247058823529412,
#    0.930011862396204,
#    0.9198520345252774,
#    0.8853267570900123,
#    0.9251207729468599,
#    0.9008363201911589,
#    0.9031476997578692,
#    0.9029126213592233,
#    0.9199522102747909],
#   'auc_score_mixmhc': [0.9675426341651412,
#    0.9608506850792965,
#    0.9543144492590809,
#    0.9554427390791028,
#    0.9503666666666666,
#    0.9644467010105013,
#    0.9629988515647431,
#    0.9502240100202332,
#    0.9367521367521368,
#    0.9704011375542584]},
#  'HLA-DRB401-01': {'accuracy': [0.7554858934169278,
#    0.7398119122257053,
#    0.6990595611285266,
#    0.7554858934169278,
#    0.7523510971786834,
#    0.7210031347962382,
#    0.7210031347962382,
#    0.7115987460815048,
#    0.7515723270440252,
#    0.7358490566037735,
#    0.7424749163879598,
#    0.7725752508361204,
#    0.7190635451505016,
#    0.7090301003344481,
#    0.68561872909699,
#    0.725752508361204,
#    0.7959866220735786,
#    0.7190635451505016,
#    0.7625418060200669,
#    0.7625418060200669,
#    0.7241379310344828,
#    0.7648902821316614,
#    0.7178683385579937,
#    0.7586206896551724,
#    0.7272727272727273,
#    0.7774294670846394,
#    0.7774294670846394,
#    0.7210031347962382,
#    0.7169811320754716,
#    0.7547169811320755,
#    0.7959866220735786,
#    0.7859531772575251,
#    0.7959866220735786,
#    0.7525083612040134,
#    0.7558528428093646,
#    0.8093645484949833,
#    0.7859531772575251,
#    0.7692307692307693,
#    0.7892976588628763,
#    0.8160535117056856],
#   'precision': [0.7898089171974523,
#    0.7402597402597403,
#    0.6296296296296297,
#    0.7368421052631579,
#    0.7133333333333334,
#    0.6709677419354839,
#    0.6838235294117647,
#    0.7152317880794702,
#    0.7483870967741936,
#    0.6758620689655173,
#    0.7564102564102564,
#    0.7792207792207793,
#    0.7012987012987013,
#    0.7202380952380952,
#    0.6689655172413793,
#    0.6729559748427673,
#    0.8066666666666666,
#    0.7394366197183099,
#    0.8102189781021898,
#    0.7304964539007093,
#    0.8785046728971962,
#    0.8660714285714286,
#    0.7307692307692307,
#    0.8253968253968254,
#    0.78,
#    0.8256880733944955,
#    0.8617021276595744,
#    0.8777777777777778,
#    0.7704918032786885,
#    0.7478260869565218,
#    0.7962962962962963,
#    0.7848101265822784,
#    0.7575757575757576,
#    0.7485714285714286,
#    0.7302631578947368,
#    0.7857142857142857,
#    0.7986577181208053,
#    0.782312925170068,
#    0.8079470198675497,
#    0.7956204379562044],
#   'recall': [0.7337278106508875,
#    0.7261146496815286,
#    0.7391304347826086,
#    0.7924528301886793,
#    0.7482517482517482,
#    0.7323943661971831,
#    0.6690647482014388,
#    0.6878980891719745,
#    0.7435897435897436,
#    0.725925925925926,
#    0.7515923566878981,
#    0.7792207792207793,
#    0.7397260273972602,
#    0.7515527950310559,
#    0.6783216783216783,
#    0.781021897810219,
#    0.7908496732026143,
#    0.6907894736842105,
#    0.7115384615384616,
#    0.7573529411764706,
#    0.5562130177514792,
#    0.6178343949044586,
#    0.5507246376811594,
#    0.6540880503144654,
#    0.5454545454545454,
#    0.6338028169014085,
#    0.5827338129496403,
#    0.5031847133757962,
#    0.6025641025641025,
#    0.6370370370370371,
#    0.821656050955414,
#    0.8051948051948052,
#    0.8561643835616438,
#    0.8136645962732919,
#    0.7762237762237763,
#    0.8029197080291971,
#    0.7777777777777778,
#    0.756578947368421,
#    0.782051282051282,
#    0.8014705882352942],
#   'f1_score': [0.7607361963190185,
#    0.7331189710610932,
#    0.68,
#    0.7636363636363637,
#    0.7303754266211604,
#    0.7003367003367004,
#    0.6763636363636364,
#    0.7012987012987013,
#    0.7459807073954984,
#    0.7,
#    0.7539936102236422,
#    0.7792207792207793,
#    0.72,
#    0.7355623100303952,
#    0.6736111111111112,
#    0.722972972972973,
#    0.7986798679867987,
#    0.7142857142857143,
#    0.757679180887372,
#    0.7436823104693141,
#    0.6811594202898551,
#    0.7211895910780669,
#    0.628099173553719,
#    0.7298245614035088,
#    0.6419753086419753,
#    0.7171314741035857,
#    0.6952789699570815,
#    0.6396761133603239,
#    0.6762589928057554,
#    0.688,
#    0.8087774294670846,
#    0.7948717948717948,
#    0.8038585209003215,
#    0.7797619047619048,
#    0.752542372881356,
#    0.7942238267148014,
#    0.7880794701986755,
#    0.7692307692307693,
#    0.7947882736156352,
#    0.7985347985347986],
#   'auc': [0.8413017751479289,
#    0.8258237005583079,
#    0.783609576427256,
#    0.8369300314465409,
#    0.8251748251748252,
#    0.8087451261239755,
#    0.7693045563549161,
#    0.8118660061335221,
#    0.8496755302310859,
#    0.8176280105241854,
#    0.8151520588499148,
#    0.8446932377966861,
#    0.814173157847614,
#    0.8148798271671618,
#    0.7690066343912497,
#    0.820266738758223,
#    0.8951114692452323,
#    0.7960526315789475,
#    0.8377712031558185,
#    0.8360700108264165,
#    0.8134122287968442,
#    0.8546827081858929,
#    0.7740411562174714,
#    0.8247051886792452,
#    0.7865543547361729,
#    0.8539428662369698,
#    0.8266187050359712,
#    0.8065188330581111,
#    0.7951883507439063,
#    0.8134183363691561,
#    0.8693818964743876,
#    0.8594267801164355,
#    0.869773480168323,
#    0.8461607705464039,
#    0.8473641742872513,
#    0.8887086599981977,
#    0.8955591368967678,
#    0.8512352309344791,
#    0.8623363815671508,
#    0.8848791050162397],
#   'accuracy_mixmhc': [0.6792452830188679,
#    0.7138364779874213,
#    0.6792452830188679,
#    0.6949685534591195,
#    0.6352201257861635,
#    0.6698113207547169,
#    0.6477987421383647,
#    0.6761006289308176,
#    0.6226415094339622,
#    0.6981132075471698],
#   'precision_mixmhc': [0.6359447004608295,
#    0.6617647058823529,
#    0.6029411764705882,
#    0.6394230769230769,
#    0.5748792270531401,
#    0.5825688073394495,
#    0.5700483091787439,
#    0.6186046511627907,
#    0.5821596244131455,
#    0.6009852216748769],
#   'recall_mixmhc': [0.8571428571428571,
#    0.8598726114649682,
#    0.8541666666666666,
#    0.8580645161290322,
#    0.8095238095238095,
#    0.900709219858156,
#    0.8368794326241135,
#    0.8636363636363636,
#    0.8,
#    0.8905109489051095],
#   'f1_score_mixmhc': [0.7301587301587301,
#    0.7479224376731302,
#    0.7068965517241379,
#    0.7327823691460055,
#    0.672316384180791,
#    0.7075208913649025,
#    0.6781609195402298,
#    0.7208672086720868,
#    0.6739130434782609,
#    0.7176470588235294],
#   'auc_score_mixmhc': [0.7847252442932311,
#    0.8359971515607073,
#    0.8086486270753512,
#    0.8423906590144469,
#    0.761188686000716,
#    0.8207917618303482,
#    0.8048643667107425,
#    0.7860112448527083,
#    0.7514545814367704,
#    0.8244747348469572]},
#  'HLA-DRB501-01': {'accuracy': [0.7740384615384616,
#    0.7387820512820513,
#    0.782051282051282,
#    0.7644230769230769,
#    0.7724358974358975,
#    0.7227564102564102,
#    0.7483974358974359,
#    0.7435897435897436,
#    0.7483974358974359,
#    0.7548076923076923,
#    0.7609170305676856,
#    0.75764192139738,
#    0.7925764192139738,
#    0.7751091703056768,
#    0.7641921397379913,
#    0.7489082969432315,
#    0.7628415300546448,
#    0.7901639344262295,
#    0.7683060109289618,
#    0.7704918032786885,
#    0.7387820512820513,
#    0.7227564102564102,
#    0.7580128205128205,
#    0.7323717948717948,
#    0.7323717948717948,
#    0.7211538461538461,
#    0.7451923076923077,
#    0.7131410256410257,
#    0.7467948717948718,
#    0.7355769230769231,
#    0.8155021834061136,
#    0.7947598253275109,
#    0.8067685589519651,
#    0.7936681222707423,
#    0.834061135371179,
#    0.8034934497816594,
#    0.825136612021858,
#    0.8032786885245902,
#    0.7879781420765027,
#    0.7846994535519126],
#   'precision': [0.8734793187347932,
#    0.8909574468085106,
#    0.9122807017543859,
#    0.8833746898263027,
#    0.9060913705583756,
#    0.8840970350404312,
#    0.8814432989690721,
#    0.9142857142857143,
#    0.8669950738916257,
#    0.8560975609756097,
#    0.7414529914529915,
#    0.7479338842975206,
#    0.784,
#    0.7908366533864541,
#    0.7367256637168141,
#    0.7408207343412527,
#    0.7319148936170212,
#    0.7941834451901566,
#    0.7936842105263158,
#    0.7319587628865979,
#    0.9357798165137615,
#    0.9409937888198758,
#    0.9460227272727273,
#    0.9093484419263456,
#    0.9351032448377581,
#    0.94375,
#    0.9273255813953488,
#    0.9335260115606936,
#    0.9255014326647565,
#    0.940251572327044,
#    0.8108108108108109,
#    0.8044444444444444,
#    0.813953488372093,
#    0.8351409978308026,
#    0.8293838862559242,
#    0.8053691275167785,
#    0.8175519630484989,
#    0.8089887640449438,
#    0.8263736263736263,
#    0.7819905213270142],
#   'recall': [0.8013392857142857,
#    0.7330415754923414,
#    0.7827956989247312,
#    0.7807017543859649,
#    0.7727272727272727,
#    0.7161572052401747,
#    0.7549668874172185,
#    0.7348643006263048,
#    0.7736263736263737,
#    0.7887640449438202,
#    0.7797752808988764,
#    0.7835497835497836,
#    0.8270042194092827,
#    0.7971887550200804,
#    0.7744186046511627,
#    0.7571743929359823,
#    0.7908045977011494,
#    0.7802197802197802,
#    0.7678207739307535,
#    0.8160919540229885,
#    0.6830357142857143,
#    0.6630196936542669,
#    0.7161290322580646,
#    0.7039473684210527,
#    0.6861471861471862,
#    0.6593886462882096,
#    0.7041942604856513,
#    0.6743215031315241,
#    0.7098901098901099,
#    0.6719101123595506,
#    0.8089887640449438,
#    0.7835497835497836,
#    0.8122362869198312,
#    0.7730923694779116,
#    0.813953488372093,
#    0.7947019867549668,
#    0.8137931034482758,
#    0.7912087912087912,
#    0.7657841140529531,
#    0.7586206896551724],
#   'f1_score': [0.8358556461001164,
#    0.8043217286914766,
#    0.8425925925925926,
#    0.8288707799767171,
#    0.8341121495327103,
#    0.7913148371531966,
#    0.8133174791914387,
#    0.8148148148148148,
#    0.8176538908246226,
#    0.8210526315789474,
#    0.76013143483023,
#    0.7653276955602537,
#    0.8049281314168378,
#    0.794,
#    0.7551020408163265,
#    0.7489082969432315,
#    0.7602209944751381,
#    0.7871396895787139,
#    0.7805383022774327,
#    0.7717391304347826,
#    0.7896774193548387,
#    0.7779204107830552,
#    0.8151774785801713,
#    0.7935723114956736,
#    0.7915106117353309,
#    0.7763496143958869,
#    0.8005018820577164,
#    0.7830303030303031,
#    0.8034825870646766,
#    0.783748361730013,
#    0.8098987626546682,
#    0.793859649122807,
#    0.8130939809926082,
#    0.8029197080291971,
#    0.8215962441314554,
#    0.8,
#    0.815668202764977,
#    0.8,
#    0.7949260042283298,
#    0.7701283547257877],
#   'auc': [0.8332741477272729,
#    0.8206213393781364,
#    0.8602691553391493,
#    0.8354349415204678,
#    0.8590200951312061,
#    0.8100897037933393,
#    0.8227928172159611,
#    0.7969476639550788,
#    0.8036868456986799,
#    0.8064842131692924,
#    0.8485603187098929,
#    0.8444323664587982,
#    0.8728640433778184,
#    0.8531590476739495,
#    0.8478179730117714,
#    0.8244627846990784,
#    0.853941570881226,
#    0.8690826564739609,
#    0.8436094992890903,
#    0.866044061302682,
#    0.8458172686688311,
#    0.8635726359097997,
#    0.8565496720091972,
#    0.8337510442773601,
#    0.8646852119074343,
#    0.8622941547850792,
#    0.8703510062868725,
#    0.8460010078468073,
#    0.8538331490994212,
#    0.8474860335195531,
#    0.8819580619766694,
#    0.8814148406659419,
#    0.8884099891173607,
#    0.875439557272151,
#    0.9004450186620729,
#    0.8778052722669605,
#    0.9089128352490422,
#    0.8782369804108935,
#    0.862607116781309,
#    0.8722078544061302],
#   'accuracy_mixmhc': [0.7603448275862069,
#    0.7879310344827586,
#    0.7517241379310344,
#    0.7810344827586206,
#    0.7530224525043178,
#    0.7443868739205527,
#    0.7875647668393783,
#    0.7789291882556131,
#    0.7409326424870466,
#    0.7512953367875648],
#   'precision_mixmhc': [0.8333333333333334,
#    0.8407494145199064,
#    0.8080357142857143,
#    0.8219780219780219,
#    0.8107476635514018,
#    0.806378132118451,
#    0.8371559633027523,
#    0.8366890380313199,
#    0.7907488986784141,
#    0.7973273942093542],
#   'recall_mixmhc': [0.8468677494199536,
#    0.8671497584541062,
#    0.861904761904762,
#    0.8904761904761904,
#    0.8484107579462102,
#    0.8489208633093526,
#    0.8752997601918465,
#    0.8717948717948718,
#    0.8671497584541062,
#    0.8710462287104623],
#   'f1_score_mixmhc': [0.8400460299194477,
#    0.8537455410225921,
#    0.8341013824884793,
#    0.8548571428571429,
#    0.8291517323775388,
#    0.8271028037383178,
#    0.8558030480656507,
#    0.8538812785388128,
#    0.8271889400921659,
#    0.8325581395348837],
#   'auc_score_mixmhc': [0.8130537691337454,
#    0.858724754088819,
#    0.8175000000000001,
#    0.8579017857142857,
#    0.8287214152164534,
#    0.8194259407288983,
#    0.8584761820173492,
#    0.8366433566433568,
#    0.8217171717171716,
#    0.8413929440389294]}}

# %% [markdown]
# # Boxplotes

# %%
# Load metrics
def load_metrics(file_path):
    with open(file_path, "r") as f:
        return json.load(f)

# Dictionary to store metrics per allele
metrics_per_allele = {}

for file_path in files:
    metrics = load_metrics(file_path)
    for allele, folds in metrics.items():
        if allele not in metrics_per_allele:
            metrics_per_allele[allele] = {}
        
        for metric, values in folds.items():
            if file_path == file_path_mhcpred and not metric.endswith("_mixmhc"):
                continue  # Keep only _mixmhc metrics for file_path_mhcpred
            
            if metric not in metrics_per_allele[allele]:
                metrics_per_allele[allele][metric] = []
            
            metrics_per_allele[allele][metric].extend(values)

# Generate boxplots
output_dir = "C:\Projects\grandmaster\notebooks\plots"
os.makedirs(output_dir, exist_ok=True)

for allele, metrics in metrics_per_allele.items():
    for metric, values in metrics.items():
        plt.figure(figsize=(8, 6))
        sns.boxplot(y=values)
        plt.title(f"{allele} - {metric}")
        plt.ylabel(metric)
        plt.savefig(os.path.join(output_dir, f"{allele}_{metric}.png"))
        plt.close()

# %%
import json
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# File paths
file_path_base_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_nb\metrics.json"
file_path_base_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_randomes\metrics.json"
file_path_new_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_nb\metrics.json"
file_path_new_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_randomes\metrics.json"
file_path_mhcpred = r"C:\Projects\grandmaster\notebooks\mixmhc_metrics.json"
files = [file_path_base_nb, file_path_base_r, file_path_new_nb, file_path_new_r, file_path_mhcpred]

# Load metrics
def load_metrics(file_path):
    with open(file_path, "r") as f:
        return json.load(f)

# Dictionary to store metrics per allele
metrics_per_allele = {}
file_labels = {
    file_path_base_nb: "Base_NB",
    file_path_base_r: "Base_R",
    file_path_new_nb: "New_NB",
    file_path_new_r: "New_R",
    file_path_mhcpred: "MHCPred"
}

for file_path in files:
    metrics = load_metrics(file_path)
    for allele, folds in metrics.items():
        if allele not in metrics_per_allele:
            metrics_per_allele[allele] = []
        
        for fold_data in folds:  # Iterate through each fold's dictionary
            if not isinstance(fold_data, dict):
                print(f"Unexpected format in {file_path} for allele {allele}: {type(fold_data)}")
                continue

            for metric, values in fold_data.items():
                if file_path == file_path_mhcpred and not metric.endswith("_mixmhc"):
                    continue  # Keep only _mixmhc metrics for file_path_mhcpred
                
                for fold_idx, value in enumerate(values if isinstance(values, list) else [values]):
                    metrics_per_allele[allele].append({
                        "Metric": metric,
                        "Value": value,
                        "Fold": fold_idx,
                        "Dataset": file_labels[file_path]
                    })

# Generate boxplots
output_dir = r"C:\Projects\grandmaster\notebooks\plots"
os.makedirs(output_dir, exist_ok=True)

for allele, data in metrics_per_allele.items():
    df = pd.DataFrame(data)
    for metric in df["Metric"].unique():
        plt.figure(figsize=(10, 6))
        sns.boxplot(x="Dataset", y="Value", data=df[df["Metric"] == metric])
        plt.title(f"{allele} - {metric}")
        plt.ylabel(metric)
        plt.xlabel("Dataset")
        plt.xticks(rotation=45)
        plt.savefig(os.path.join(output_dir, f"{allele}_{metric}.png"))
        plt.close()

# %%
import json
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import re

# File paths
file_path_base_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_nb\metrics.json"
file_path_base_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_randomes\metrics.json"
file_path_new_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_nb\metrics.json"
file_path_new_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_randomes\metrics.json"
file_path_mhcpred = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\2\10fold\10foldmetrics.json"
files = [file_path_base_nb, file_path_base_r, file_path_new_nb, file_path_new_r, file_path_mhcpred]

# Load metrics
def load_metrics(file_path):
    with open(file_path, "r") as f:
        return json.load(f)

# Dictionary to store metrics per allele
metrics_per_allele = {}
file_labels = {
    file_path_base_nb: "Base_NB",
    file_path_base_r: "Base_R",
    file_path_new_nb: "New_NB",
    file_path_new_r: "New_R",
    file_path_mhcpred: "MHCPred"
}

# Mapping MHCPred metrics to match other dataset names
metric_name_mapping = {
    "auc_score": "auc",
    "accuracy_mixmhc":'accuracy',
    'precision_mixmhc':'precision',
    'recall_mixmhc':"recall",
    'f1_score':'f1_score_mixmhc'

}
for file_path in files:
    metrics = load_metrics(file_path)
    for allele, folds in metrics.items():
        if allele not in metrics_per_allele:
            metrics_per_allele[allele] = []
        
        for fold_idx, fold_data in enumerate(folds):  # Iterate through each fold's dictionary
            if not isinstance(fold_data, dict):
                print(f"Unexpected format in {file_path} for allele {allele}: {type(fold_data)}")
                continue

            for metric, value in fold_data.items():
                # Normalize MHCPred metric names
                base_metric = metric_name_mapping.get(metric, metric)  # Map specific names
                
                if file_path == file_path_mhcpred and not metric.endswith("_mixmhc"):
                    continue  # Keep only _mixmhc metrics for file_path_mhcpred
                
                metrics_per_allele[allele].append({
                    "Metric": base_metric,
                    "Value": value,
                    "Dataset": file_labels[file_path]
                })

# Generate boxplots
output_dir = r"C:\Projects\grandmaster\notebooks\plots"
os.makedirs(output_dir, exist_ok=True)

for allele, data in metrics_per_allele.items():
    df = pd.DataFrame(data)
    for metric in df["Metric"].unique():
        plt.figure(figsize=(10, 6))
        sns.boxplot(x="Dataset", y="Value", data=df[df["Metric"] == metric])
        plt.title(f"{allele} - {metric}")
        plt.ylabel(metric)
        plt.xlabel("Dataset")
        plt.xticks(rotation=45)
        plt.savefig(os.path.join(output_dir, f"{allele}_{metric}.png"))
        plt.close()

# %%
metrics_per_alleleimport json
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# File paths
file_path_base_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_nb\metrics.json"
file_path_base_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_randomes\metrics.json"
file_path_new_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_nb\metrics.json"
file_path_new_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_randomes\metrics.json"
file_path_mhcpred = r"C:\Projects\grandmaster\notebooks\mixmhc_metrics.json"
files = [file_path_base_nb, file_path_base_r, file_path_new_nb, file_path_new_r, file_path_mhcpred]

# Load metrics
def load_metrics(file_path):
    with open(file_path, "r") as f:
        return json.load(f)

# Dictionary to store metrics per allele
metrics_per_allele = {}
file_labels = {
    file_path_base_nb: "Base_NB",
    file_path_base_r: "Base_R",
    file_path_new_nb: "New_NB",
    file_path_new_r: "New_R",
    file_path_mhcpred: "MHCPred"
}

for file_path in files:
    metrics = load_metrics(file_path)
    for allele, folds in metrics.items():
        if allele not in metrics_per_allele:
            metrics_per_allele[allele] = []
        
        for fold_data in folds:  # Iterate through each fold's dictionary
            if not isinstance(fold_data, dict):
                print(f"Unexpected format in {file_path} for allele {allele}: {type(fold_data)}")
                continue

            for metric, values in fold_data.items():
                if file_path == file_path_mhcpred and not metric.endswith("_mixmhc"):
                    continue  # Keep only _mixmhc metrics for file_path_mhcpred
                
                for fold_idx, value in enumerate(values if isinstance(values, list) else [values]):
                    metrics_per_allele[allele].append({
                        "Metric": metric,
                        "Value": value,
                        "Fold": fold_idx,
                        "Dataset": file_labels[file_path]
                    })

# Generate boxplots
output_dir = r"C:\Projects\grandmaster\notebooks\plots"
os.makedirs(output_dir, exist_ok=True)

for allele, data in metrics_per_allele.items():
    df = pd.DataFrame(data)
    for metric in df["Metric"].unique():
        plt.figure(figsize=(10, 6))
        sns.boxplot(x="Dataset", y="Value", data=df[df["Metric"] == metric])
        plt.title(f"{allele} - {metric}")
        plt.ylabel(metric)
        plt.xlabel("Dataset")
        plt.xticks(rotation=45)
        plt.savefig(os.path.join(output_dir, f"{allele}_{metric}.png"))
        plt.close()
# Out:
# {'HLA-DRB101-01': [{'Metric': 'accuracy',
#    'Value': 0.7478260869565218,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9174630755864466,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7410526315789474,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.8198757763975155,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8311824138659902,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7717391304347826,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9286912751677853,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7676837725381415,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.8405466970387244,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8462074589312721,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7706521739130435,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9153122326775022,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7681263460157932,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.8352849336455894,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8429539837249527,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7429347826086956,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.8976982097186701,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7489331436699858,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.8165955796820473,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8049578501615853,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7347826086956522,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9133858267716536,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7285415212840195,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.8105590062111802,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8131032129636456,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7396739130434783,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.905790838375108,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7390691114245416,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.8139805825242719,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8242192461179553,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7326086956521739,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.903056768558952,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7307420494699647,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8078125, 'Fold': 0, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.7991585948867179,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7478260869565218,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.8949615713065756,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7544996400287977,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.81875, 'Fold': 0, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8079844964952692,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.75, 'Fold': 0, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9072164948453608,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.75, 'Fold': 0, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.8211508553654744,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.824014066445707,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7438825448613376,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.8966087675765095,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7580419580419581,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.821523304281925,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8009121685160805,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7432909604519774,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.7247956403269755,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.7671232876712328,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7453590192644484,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.8202238781767425,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7387005649717514,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.7375415282392026,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.7628865979381443,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.75, 'Fold': 0, 'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.8192310091912545,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.713276836158192,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.7219061166429588,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.7068245125348189,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7142857142857143,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.7903021765330313,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7588276836158192,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.75, 'Fold': 0, 'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.7655913978494624,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7577155019510464,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.8361440974950303,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7521186440677966,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.7362491716368456,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.7851590106007067,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7599179206566348,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.8394403146048363,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7630649717514124,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.7631763879128601,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.7647887323943662,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7639817094618361,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.8439048597534213,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7213983050847458,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.7178619756427604,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.7404047452896022,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7289591205771213,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.8009564203720433,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7482344632768362,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.7454050374404356,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.7635983263598326,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7543920082673097,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.8338042192173318,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7470858353938538,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.7261987491313412,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.7644476956839795,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.744832501781896,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.8231988599342024,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7559166372306605,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.7510373443983402,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.766407904022583,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7586447782046805,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.832682849896039,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.6923913043478261,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9198435972629521,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6603508771929825,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7687908496732027,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8027588247727754,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.6864130434782608,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9472595656670114,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6352288488210819,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7604815276048152,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8348660779626288,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.6918478260869565,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9302083333333333,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6410624551328069,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7590310242243944,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8241527227058912,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.6695652173913044,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.933695652173913,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6109530583214794,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7386070507308684,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8101544729303644,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.6652173913043479,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9331919406150583,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6140963014654571,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7407407407407407,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.7949354543911418,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.6679347826086957,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9419496166484118,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6064880112834978,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7378807378807379,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8205711602350283,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.6755434782608696,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9416846652267818,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6162544169611307,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7449807774455361,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8123234254832675,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.6923913043478261,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9354497354497354,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6364290856731462,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7574978577549272,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.818054112212043,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.6934782608695652,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9368530020703933,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6427556818181818,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7624262847514743,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8096812855113635,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.6884176182707994,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9422084623323014,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6384615384615384,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7611504793664027,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8245550293227555,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7817796610169492,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.7829286239882266,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7671232876712328,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7749453750910416,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8547017161332491,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7623587570621468,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.7896296296296297,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7326460481099656,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7600713012477719,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8403901104797271,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7680084745762712,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8113509192645884,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7068245125348189,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7554893933755117,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8448885993407347,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7980225988700564,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8010241404535479,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7849462365591398,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7929036929761043,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8756449492795374,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7786016949152542,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.7966867469879518,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7477031802120141,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7714181553044113,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.854026448152295, 'Fold': 0, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7612994350282486,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.7664756446991404,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7535211267605634,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7599431818181818,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8314652076766548,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.763771186440678,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.7952086553323029,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7180739706908583,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7546754675467546,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8382001499426117,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.763771186440678,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.79265493496557,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7224546722454672,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7559284932506385,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8459674410345123,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7813493465206641,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.7675250357653791,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7849305047549379,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.776130198915009,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8717885681621036,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7855881314023313,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.7956204379562044,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7692307692307693,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7822030857552924,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8590004781302809,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7849944008958567,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8720059880239521,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8454281567489115,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8585114222549742,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8335876803551608,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7827547592385219,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8648449039881831,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8510174418604651,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8578754578754578,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8260236457742485,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.776595744680851,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8527422990232908,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8482810164424515,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8505058074185088,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8314940676382662,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7788353863381859,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8626126126126126,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8442321822189567,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8533234311177126,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.839250551065393,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7777155655095185,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8677563150074294,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8421052631578947,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8547383827296011,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8228736946909451,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7704367301231803,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8750963762528913,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8206796818510484,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8470149253731343,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8228147892971908,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7704367301231803,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8697318007662835,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8254545454545454,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8470149253731343,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8291944260119443,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7737961926091825,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8584269662921349,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8420279206465834,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8501483679525222,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8218602238838225,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7721164613661814,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.849772382397572,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8427389014296464,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8462410275783906,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8278348835026748,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.773109243697479,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8607784431137725,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8400292184075968,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8502772643253235,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8317149660055065,
#    'Fold': 0,
#    'Dataset': 'MHCPred'}],
#  'HLA-DRB103-01': [{'Metric': 'accuracy',
#    'Value': 0.8396946564885496,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.27700463883366466,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7385159010600707,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.40289156626506023,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8772224165309658,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.8522447923405356,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.3385518590998043,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.8021638330757341,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.4761467889908257,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9136199617027647,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.8951998964937249,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.4106280193236715,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.8673469387755102,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.5573770491803278,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9494164911448405,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.8862724802691163,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.38497652582159625,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.841025641025641,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.5281803542673108,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9435052784716838,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.8399534221762195,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.3187960687960688,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.8021638330757341,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.4562637362637363,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8985845649134645,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.8865312459567861,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.40364188163884673,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.8539325842696629,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.5481710458526533,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9458265323225147,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.8574201060939319,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.32745762711864407,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.8145025295109612,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.4671179883945841,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9109866888739326,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.8959627329192547,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.4180194805194805,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.8554817275747508,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.5616139585605234,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9451034674389698,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.8933747412008282,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.41825396825396827,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.8527508090614887,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.5612353567625133,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9530941196819285,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.8795289855072463,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
#    'Value': 0.3981348637015782,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'recall',
#    'Value': 0.8578052550231839,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.5438510534051936,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9420581930398237,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.8733660130718954,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.8667687595712098,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.8927444794952681,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8795648795648796,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.9367213815965354,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8496732026143791,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.8500797448165869,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.85553772070626,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8528, 'Fold': 0, 'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.9252770262510582,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8585445625511039,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.8276923076923077,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.8981636060100167,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8614891913530824,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.929802876589187,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8634505314799673,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.85625, 'Fold': 0, 'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.8796147672552167,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8677751385589866,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.9375093632958802,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8111201962387572,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.8084772370486656,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.8253205128205128,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.816812053925456,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.9023452549120329,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8266557645134914,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.8273615635179153,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.8273615635179153,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8273615635179153,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.8964073105373791,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.856909239574816,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.8427480916030534,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.8846153846153846,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8631743549648163,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.9341209708488505,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8421913327882257,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.8184764991896273,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.8617747440273038,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8395677472984207,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.9167197989723589,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8544562551103843,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.8300970873786407,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.8754266211604096,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8521594684385382,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.9245342663187617,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.856909239574816,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.84185303514377,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.8739635157545605,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8576078112286412,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.9225592467768684,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.9584681071289947,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.6881720430107527,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7915194346289752,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7362366474938373,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9742885134591829,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.9465648854961832,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.6519480519480519,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7758887171561051,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7085391672547636,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9431333633344348,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.957950575753655,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.697151424287856,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7908163265306123,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7410358565737052,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9500740430607195,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.9483762453098719,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.6363636363636364,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7418803418803419,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.6850828729281768,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9432549937309176,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.953939707594773,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.7001375515818432,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7867078825347759,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7409024745269287,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9619626918408207,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.9563979816276362,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.7048710601719198,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7897271268057785,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.744890234670704,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9674161369294775,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.9505757536550653,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.6522366522366523,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7622259696458684,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.702954898911353,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9416952922360271,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.9607919254658385,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.7296466973886329,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7890365448504983,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7581803671189146,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.9703539889021812,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.9484989648033126,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.6558073654390935,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7491909385113269,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.6993957703927492,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.937365554690736,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.9334886128364389,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.5792610250297974,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7511591962905718,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.6541049798115747,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.935622833771372,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.8700980392156863,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8938640132669984,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8501577287066246,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8714632174616006,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.942944982088435, 'Fold': 0, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8513071895424836,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8668885191347754,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8362760834670947,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8513071895424836,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.9241419464082067,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.874897792313982,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8631921824104235,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8848080133555927,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8738664468260511,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.9504917383673643,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8773507767784138,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.9215686274509803,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8298555377207063,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8733108108108109,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.9271294810058855,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.848732624693377,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8512, 'Fold': 0, 'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8525641025641025,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8518815052041633,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.929556739865588, 'Fold': 0, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8111201962387572,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8123980424143556,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8110749185667753,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8117359413202934,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.9030209185774725,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8904333605887162,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8951612903225806,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8894230769230769,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8922829581993569,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.9497185480073628,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8070318887980377,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.7859477124183006,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8208191126279863,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8030050083472454,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8919047797643606,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8732624693376942,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8841354723707665,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8464163822525598,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8648648648648649,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.9353920092584158,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8626328699918234,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8606965174129353,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8606965174129353,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8606965174129353,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.9386428074680361,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.6984332513272045,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.19071076706544687,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.9492119089316988,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.31760914151772635,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.9393950524414565,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7093098536838016,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.21557522123893805,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.9545454545454546,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.3517181634421022,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.9446634352676744,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7041305192282792,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.1985790408525755,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.9506802721088435,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.32853364678225094,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.9448618480328362,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7034831024213388,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.1963778409090909,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.9534482758620689,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.32567726737338043,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.9447953627134353,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7029651689757866,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.21274373259052926,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.9487577639751553,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.34755403868031853,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.9359003184118191,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.708015020069921,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.21048901488306165,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.9565217391304348,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.3450479233226837,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.9449639052935124,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.693124433510294,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.19190871369294607,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.9438775510204082,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.31896551724137934,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.9416751283554767,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7103457205749061,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.2042507204610951,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.9529411764705882,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.33639869474933254,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.94976421545049,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.6999481999481999,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.20396108408617095,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.9575856443719413,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.3362933256946434,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.9462663301373142,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.707977207977208,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.21774193548387097,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.9627906976744186,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.3551615670574778,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.9454679587658676,
#    'Fold': 0,
#    'Dataset': 'MHCPred'}],
#  'HLA-DRB107-01': [{'Metric': 'accuracy',
#    'Value': 0.8362350380848749,
#    'Fold': 0,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision',
# ...
#    'Value': 0.7602209944751381,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.853941570881226,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7901639344262295,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.7941834451901566,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.7802197802197802,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7871396895787139,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.8690826564739609,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7683060109289618,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.7936842105263158,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.7678207739307535,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7805383022774327,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.8436094992890903,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7704918032786885,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'precision',
#    'Value': 0.7319587628865979,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'recall',
#    'Value': 0.8160919540229885,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7717391304347826,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'auc',
#    'Value': 0.866044061302682,
#    'Fold': 0,
#    'Dataset': 'Base_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7387820512820513,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9357798165137615,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6830357142857143,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7896774193548387,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8458172686688311,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7227564102564102,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9409937888198758,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6630196936542669,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7779204107830552,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8635726359097997,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7580128205128205,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9460227272727273,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7161290322580646,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.8151774785801713,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8565496720091972,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7323717948717948,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9093484419263456,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7039473684210527,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7935723114956736,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8337510442773601,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7323717948717948,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9351032448377581,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6861471861471862,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7915106117353309,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8646852119074343,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7211538461538461,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.94375, 'Fold': 0, 'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6593886462882096,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7763496143958869,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8622941547850792,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7451923076923077,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9273255813953488,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7041942604856513,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.8005018820577164,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8703510062868725,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7131410256410257,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9335260115606936,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6743215031315241,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.7830303030303031,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8460010078468073,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7467948717948718,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.9255014326647565,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.7098901098901099,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.8034825870646766,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8538331490994212,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.7355769230769231,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'precision',
#    'Value': 0.940251572327044,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'recall',
#    'Value': 0.6719101123595506,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'f1_score',
#    'Value': 0.783748361730013,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'auc',
#    'Value': 0.8474860335195531,
#    'Fold': 0,
#    'Dataset': 'New_NB'},
#   {'Metric': 'accuracy',
#    'Value': 0.8155021834061136,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8108108108108109,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8089887640449438,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8098987626546682,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8819580619766694,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7947598253275109,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8044444444444444,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7835497835497836,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.793859649122807,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8814148406659419,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8067685589519651,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.813953488372093,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8122362869198312,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8130939809926082,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8884099891173607,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7936681222707423,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8351409978308026,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7730923694779116,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8029197080291971,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.875439557272151, 'Fold': 0, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.834061135371179,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8293838862559242,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.813953488372093,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.8215962441314554,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.9004450186620729,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8034934497816594,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8053691275167785,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7947019867549668,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8, 'Fold': 0, 'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8778052722669605,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.825136612021858,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8175519630484989,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.8137931034482758,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.815668202764977,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.9089128352490422,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.8032786885245902,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8089887640449438,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7912087912087912,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8, 'Fold': 0, 'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8782369804108935,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7879781420765027,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.8263736263736263,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7657841140529531,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7949260042283298,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.862607116781309, 'Fold': 0, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy',
#    'Value': 0.7846994535519126,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'precision',
#    'Value': 0.7819905213270142,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'recall',
#    'Value': 0.7586206896551724,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'f1_score',
#    'Value': 0.7701283547257877,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'auc',
#    'Value': 0.8722078544061302,
#    'Fold': 0,
#    'Dataset': 'New_R'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7603448275862069,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8333333333333334,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8468677494199536,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8400460299194477,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8130537691337454,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7879310344827586,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8407494145199064,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8671497584541062,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8537455410225921,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.858724754088819,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7517241379310344,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8080357142857143,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.861904761904762,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8341013824884793,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8175000000000001,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7810344827586206,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8219780219780219,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8904761904761904,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8548571428571429,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8579017857142857,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7530224525043178,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8107476635514018,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8484107579462102,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8291517323775388,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8287214152164534,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7443868739205527,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.806378132118451,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8489208633093526,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8271028037383178,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8194259407288983,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7875647668393783,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8371559633027523,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8752997601918465,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8558030480656507,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8584761820173492,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7789291882556131,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.8366890380313199,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8717948717948718,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8538812785388128,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8366433566433568,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7409326424870466,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.7907488986784141,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8671497584541062,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8271889400921659,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8217171717171716,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'accuracy_mixmhc',
#    'Value': 0.7512953367875648,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'precision_mixmhc',
#    'Value': 0.7973273942093542,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'recall_mixmhc',
#    'Value': 0.8710462287104623,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'f1_score_mixmhc',
#    'Value': 0.8325581395348837,
#    'Fold': 0,
#    'Dataset': 'MHCPred'},
#   {'Metric': 'auc',
#    'Value': 0.8413929440389294,
#    'Fold': 0,
#    'Dataset': 'MHCPred'}]}

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sci_stats
from statannotations.Annotator import Annotator  # For adding statistical annotations

file_path_base_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_nb\metrics.json"
file_path_base_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_randomes\metrics.json"
file_path_new_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_nb\metrics.json"
file_path_new_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_randomes\metrics.json"
file_path_mhcpred = r"C:\Projects\grandmaster\notebooks\mixmhc_metrics.json"
files = [file_path_base_nb, file_path_base_r, file_path_new_nb, file_path_new_r, file_path_mhcpred]

# Load metrics
def load_metrics(file_path):
    with open(file_path, "r") as f:
        return json.load(f)

# Dictionary to store metrics per allele
metrics_per_allele = {}
file_labels = {
    file_path_base_nb: "Base_NB",
    file_path_base_r: "Base_R",
    file_path_new_nb: "New_NB",
    file_path_new_r: "New_R",
    file_path_mhcpred: "MHCPred"
}

metric_name_mapping = {
    "auc_score": "auc"
}

for file_path in files:
    metrics = load_metrics(file_path)
    for allele, folds in metrics.items():
        if allele not in metrics_per_allele:
            metrics_per_allele[allele] = []
        
        for fold_idx, fold_data in enumerate(folds):  # Iterate through each fold's dictionary
            if not isinstance(fold_data, dict):
                print(f"Unexpected format in {file_path} for allele {allele}: {type(fold_data)}")
                continue

            for metric, value in fold_data.items():
                # Normalize MHCPred metric names
                base_metric = metric_name_mapping.get(metric, metric)  # Map specific names
                
                if file_path == file_path_mhcpred and not metric.endswith("_mixmhc"):
                    continue  # Keep only _mixmhc metrics for file_path_mhcpred
                
                metrics_per_allele[allele].append({
                    "Metric": base_metric,
                    "Value": value,
                    "Dataset": file_labels[file_path]
                })



output_dir = r"C:\Projects\grandmaster\notebooks\plots\stars"
os.makedirs(output_dir, exist_ok=True)

# Iterate through each allele's data
for allele, data in metrics_per_allele.items():
    df = pd.DataFrame(data)

    # Iterate through each metric separately
    for metric in df["Metric"].unique():
        plt.figure(figsize=(10, 6))
        ax = sns.boxplot(x="Dataset", y="Value", data=df[df["Metric"] == metric])

        # Extract values for comparisons
        datasets = df["Dataset"].unique()
        dataset_pairs = [(datasets[i], datasets[j]) for i in range(len(datasets)) for j in range(i + 1, len(datasets))]

        # Compute p-values
        pvalues = [
            sci_stats.mannwhitneyu(
                df[(df["Dataset"] == pair[0]) & (df["Metric"] == metric)]["Value"],
                df[(df["Dataset"] == pair[1]) & (df["Metric"] == metric)]["Value"],
                alternative="two-sided"
            ).pvalue
            for pair in dataset_pairs
        ]

        # Format p-values
        formatted_pvalues = [f'p={pval:.2e}' for pval in pvalues]

        # Annotate significance with stars
        def pval_to_stars(p):
            if p < 0.001:
                return "***"
            elif p < 0.01:
                return "**"
            elif p < 0.05:
                return "*"
            else:
                return "ns"  # Not significant

        stars = [pval_to_stars(p) for p in pvalues]

        # Add annotations
        annotator = Annotator(ax, dataset_pairs, data=df[df["Metric"] == metric], x="Dataset", y="Value")
        annotator.set_pvalues(pvalues)
        annotator.annotate()


        plt.title(f"{allele} - {metric}")
        plt.ylabel(metric)
        plt.xlabel("Dataset")
        plt.xticks(rotation=45)
        plt.savefig(os.path.join(output_dir, f"{allele}_{metric}.png"))
        plt.close()
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.000e+00
# Base_R vs. New_NB: Custom statistical test, P_val:1.817e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.806e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.806e-04
# Base_R vs. New_R: Custom statistical test, P_val:3.281e-04
# Base_NB vs. New_R: Custom statistical test, P_val:2.807e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:2.461e-04
# Base_R vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.620e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:6.229e-01
# Base_NB vs. New_R: Custom statistical test, P_val:1.000e+00
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:4.727e-01
# New_NB vs. New_R: Custom statistical test, P_val:7.566e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:7.285e-03
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:5.708e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.859e-01
# New_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:7.337e-01
# Base_R vs. New_R: Custom statistical test, P_val:1.706e-03
# Base_NB vs. New_R: Custom statistical test, P_val:1.706e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:6.392e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.817e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:3.254e-01
# Base_NB vs. New_R: Custom statistical test, P_val:1.620e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:4.515e-02
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:9.082e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:2.817e-03
# Base_R vs. New_R: Custom statistical test, P_val:1.212e-01
# Base_NB vs. New_R: Custom statistical test, P_val:5.204e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:6.232e-01
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.730e-01
# Base_R vs. New_NB: Custom statistical test, P_val:4.396e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.133e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.212e-01
# Base_R vs. New_R: Custom statistical test, P_val:2.413e-01
# Base_NB vs. New_R: Custom statistical test, P_val:7.913e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:3.073e-01
# Base_R vs. New_NB: Custom statistical test, P_val:5.777e-03
# New_NB vs. New_R: Custom statistical test, P_val:6.775e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:6.776e-01
# Base_R vs. New_R: Custom statistical test, P_val:1.545e-02
# Base_NB vs. New_R: Custom statistical test, P_val:1.618e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.202e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:7.685e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:3.121e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.897e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.447e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:4.571e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.817e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:9.108e-03
# Base_R vs. New_R: Custom statistical test, P_val:2.569e-02
# Base_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:5.708e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.041e-01
# New_NB vs. New_R: Custom statistical test, P_val:7.685e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:4.515e-02
# Base_R vs. New_R: Custom statistical test, P_val:9.108e-03
# Base_NB vs. New_R: Custom statistical test, P_val:5.390e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.405e-01
# Base_R vs. New_NB: Custom statistical test, P_val:2.409e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.776e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:5.686e-03
# Base_R vs. New_R: Custom statistical test, P_val:2.411e-01
# Base_NB vs. New_R: Custom statistical test, P_val:2.569e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:4.396e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:3.298e-04
# Base_R vs. New_R: Custom statistical test, P_val:5.795e-03
# Base_NB vs. New_R: Custom statistical test, P_val:3.121e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.461e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.202e-03
# Base_NB vs. New_R: Custom statistical test, P_val:1.000e+00
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.575e-02
# Base_R vs. New_NB: Custom statistical test, P_val:5.390e-02
# New_NB vs. New_R: Custom statistical test, P_val:5.390e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.008e-03
# Base_R vs. New_R: Custom statistical test, P_val:6.776e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.447e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.827e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.008e-03
# New_NB vs. New_R: Custom statistical test, P_val:3.298e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:2.730e-01
# Base_R vs. New_R: Custom statistical test, P_val:2.123e-01
# Base_NB vs. New_R: Custom statistical test, P_val:5.828e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.211e-01
# Base_R vs. New_NB: Custom statistical test, P_val:2.575e-02
# New_NB vs. New_R: Custom statistical test, P_val:4.556e-03
# Base_NB vs. New_NB: Custom statistical test, P_val:1.400e-01
# Base_R vs. New_R: Custom statistical test, P_val:4.051e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.102e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:3.298e-04
# Base_R vs. New_R: Custom statistical test, P_val:7.913e-01
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_NB: Custom statistical test, P_val:8.501e-01
# New_NB vs. New_R: Custom statistical test, P_val:3.847e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:5.966e-01
# Base_R vs. New_R: Custom statistical test, P_val:9.618e-02
# Base_NB vs. New_R: Custom statistical test, P_val:7.566e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:4.396e-04
# Base_R vs. New_NB: Custom statistical test, P_val:4.396e-04
# New_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.620e-01
# Base_R vs. New_R: Custom statistical test, P_val:3.075e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.298e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:9.698e-01
# Base_R vs. New_NB: Custom statistical test, P_val:2.575e-02
# New_NB vs. New_R: Custom statistical test, P_val:7.285e-03
# Base_NB vs. New_NB: Custom statistical test, P_val:2.575e-02
# Base_R vs. New_R: Custom statistical test, P_val:3.847e-01
# Base_NB vs. New_R: Custom statistical test, P_val:1.859e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:6.402e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:4.571e-03
# Base_NB vs. New_R: Custom statistical test, P_val:4.725e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.461e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:8.897e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:3.847e-01
# Base_NB vs. New_R: Custom statistical test, P_val:6.232e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.575e-02
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.212e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:1.008e-03
# Base_NB vs. New_R: Custom statistical test, P_val:5.390e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:6.232e-01
# Base_R vs. New_NB: Custom statistical test, P_val:9.698e-01
# New_NB vs. New_R: Custom statistical test, P_val:4.725e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:7.336e-01
# Base_R vs. New_R: Custom statistical test, P_val:4.495e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.847e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:3.121e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.575e-02
# Base_NB vs. New_R: Custom statistical test, P_val:9.097e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_NB: Custom statistical test, P_val:4.515e-02
# New_NB vs. New_R: Custom statistical test, P_val:7.566e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.133e-02
# Base_R vs. New_R: Custom statistical test, P_val:9.698e-01
# Base_NB vs. New_R: Custom statistical test, P_val:7.337e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.413e-01
# Base_R vs. New_NB: Custom statistical test, P_val:3.642e-01
# New_NB vs. New_R: Custom statistical test, P_val:6.776e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:7.337e-01
# Base_R vs. New_R: Custom statistical test, P_val:5.708e-01
# Base_NB vs. New_R: Custom statistical test, P_val:9.097e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:6.232e-01
# Base_R vs. New_NB: Custom statistical test, P_val:5.708e-01
# New_NB vs. New_R: Custom statistical test, P_val:6.776e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:6.776e-01
# Base_R vs. New_R: Custom statistical test, P_val:6.232e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.847e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.000e+00
# Base_R vs. New_NB: Custom statistical test, P_val:2.089e-02
# New_NB vs. New_R: Custom statistical test, P_val:1.035e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:8.927e-03
# Base_R vs. New_R: Custom statistical test, P_val:9.097e-01
# Base_NB vs. New_R: Custom statistical test, P_val:6.776e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.575e-02
# Base_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.405e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.040e-01
# New_NB vs. New_R: Custom statistical test, P_val:5.706e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_R: Custom statistical test, P_val:4.117e-02
# Base_NB vs. New_R: Custom statistical test, P_val:3.075e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.706e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.726e-02
# Base_R vs. New_R: Custom statistical test, P_val:9.097e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.611e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.413e-01
# Base_R vs. New_NB: Custom statistical test, P_val:4.586e-03
# New_NB vs. New_R: Custom statistical test, P_val:1.402e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:8.501e-01
# Base_NB vs. New_R: Custom statistical test, P_val:4.274e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:7.333e-01
# Base_R vs. New_NB: Custom statistical test, P_val:7.334e-01
# New_NB vs. New_R: Custom statistical test, P_val:3.573e-03
# Base_NB vs. New_NB: Custom statistical test, P_val:3.436e-01
# Base_R vs. New_R: Custom statistical test, P_val:7.132e-03
# Base_NB vs. New_R: Custom statistical test, P_val:3.231e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:3.075e-01
# Base_R vs. New_NB: Custom statistical test, P_val:7.285e-03
# New_NB vs. New_R: Custom statistical test, P_val:1.859e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:1.706e-03
# Base_R vs. New_R: Custom statistical test, P_val:7.566e-02
# Base_NB vs. New_R: Custom statistical test, P_val:2.202e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.413e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:3.611e-03
# Base_NB vs. New_R: Custom statistical test, P_val:5.828e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.730e-01
# Base_R vs. New_NB: Custom statistical test, P_val:5.795e-03
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:3.121e-02
# Base_R vs. New_R: Custom statistical test, P_val:4.586e-03
# Base_NB vs. New_R: Custom statistical test, P_val:3.298e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_NB: Custom statistical test, P_val:4.274e-01
# New_NB vs. New_R: Custom statistical test, P_val:1.008e-03
# Base_NB vs. New_NB: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_R: Custom statistical test, P_val:2.202e-03
# Base_NB vs. New_R: Custom statistical test, P_val:3.298e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.040e-01
# Base_R vs. New_NB: Custom statistical test, P_val:3.281e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.388e-02
# Base_R vs. New_R: Custom statistical test, P_val:5.828e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.817e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:3.298e-04
# Base_R vs. New_R: Custom statistical test, P_val:5.828e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.041e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:7.054e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.121e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:4.396e-04
# Base_R vs. New_NB: Custom statistical test, P_val:3.764e-02
# New_NB vs. New_R: Custom statistical test, P_val:7.555e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.706e-03
# Base_R vs. New_R: Custom statistical test, P_val:3.598e-03
# Base_NB vs. New_R: Custom statistical test, P_val:2.109e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.133e-02
# Base_R vs. New_NB: Custom statistical test, P_val:8.501e-01
# New_NB vs. New_R: Custom statistical test, P_val:4.396e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:5.795e-03
# Base_R vs. New_R: Custom statistical test, P_val:5.828e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04

# %%
import json
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sci_stats
from statannotations.Annotator import Annotator  # For adding statistical annotations

file_path_base_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_nb\metrics.json"
file_path_base_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_randomes\metrics.json"
file_path_new_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_nb\metrics.json"
file_path_new_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_randomes\metrics.json"
file_path_mhcpred = r"C:\Projects\grandmaster\notebooks\mixmhc_metrics.json"
files = [file_path_base_nb, file_path_base_r, file_path_new_nb, file_path_new_r, file_path_mhcpred]

# Load metrics
def load_metrics(file_path):
    with open(file_path, "r") as f:
        return json.load(f)

# Dictionary to store metrics per allele
metrics_per_allele = {}
file_labels = {
    file_path_base_nb: "Base_NB",
    file_path_base_r: "Base_R",
    file_path_new_nb: "New_NB",
    file_path_new_r: "New_R",
    file_path_mhcpred: "MHCPred"
}

metric_name_mapping = {
    "auc_score": "auc"
}

# Collect allele names from all files
allele_sets = [set(load_metrics(fp).keys()) for fp in files]
common_alleles = set.intersection(*allele_sets)  # Find alleles that exist in all files

# Process metrics ensuring MHCPred aligns
for file_path in files:
    metrics = load_metrics(file_path)
    
    for allele in common_alleles:  # Only process alleles present in all datasets
        if allele not in metrics_per_allele:
            metrics_per_allele[allele] = []

        if allele not in metrics:
            print(f"Warning: {allele} missing in {file_path}")
            continue

        for fold_idx, fold_data in enumerate(metrics[allele]):  
            if not isinstance(fold_data, dict):
                print(f"Unexpected format in {file_path} for allele {allele}: {type(fold_data)}")
                continue

            for metric, value in fold_data.items():
                base_metric = metric_name_mapping.get(metric, metric)  # Normalize metric names
                
                if file_path == file_path_mhcpred and not metric.endswith("_mixmhc"):
                    continue  # Keep only _mixmhc metrics for file_path_mhcpred
                
                metrics_per_allele[allele].append({
                    "Metric": base_metric,
                    "Value": value,
                    "Dataset": file_labels[file_path]
                })

output_dir = r"C:\Projects\grandmaster\notebooks\plots\stars"
os.makedirs(output_dir, exist_ok=True)

# Plot data
for allele, data in metrics_per_allele.items():
    df = pd.DataFrame(data)

    for metric in df["Metric"].unique():
        plt.figure(figsize=(10, 6))
        ax = sns.boxplot(x="Dataset", y="Value", data=df[df["Metric"] == metric])

        # Extract values for comparisons
        datasets = df["Dataset"].unique()
        dataset_pairs = [(datasets[i], datasets[j]) for i in range(len(datasets)) for j in range(i + 1, len(datasets))]

        # Compute p-values
        pvalues = [
            sci_stats.mannwhitneyu(
                df[(df["Dataset"] == pair[0]) & (df["Metric"] == metric)]["Value"],
                df[(df["Dataset"] == pair[1]) & (df["Metric"] == metric)]["Value"],
                alternative="two-sided"
            ).pvalue
            for pair in dataset_pairs
        ]

        # Format p-values
        def pval_to_stars(p):
            if p < 0.001:
                return "***"
            elif p < 0.01:
                return "**"
            elif p < 0.05:
                return "*"
            else:
                return "ns"

        stars = [pval_to_stars(p) for p in pvalues]

        # Add annotations
        annotator = Annotator(ax, dataset_pairs, data=df[df["Metric"] == metric], x="Dataset", y="Value")
        annotator.set_pvalues(pvalues)
        annotator.annotate()

        plt.title(f"{allele} - {metric}")
        plt.ylabel(metric)
        plt.xlabel("Dataset")
        plt.xticks(rotation=45)
        plt.savefig(os.path.join(output_dir, f"{allele}_{metric}.png"))
        plt.close()
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.040e-01
# Base_R vs. New_NB: Custom statistical test, P_val:3.281e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.388e-02
# Base_R vs. New_R: Custom statistical test, P_val:5.828e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.817e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:3.298e-04
# Base_R vs. New_R: Custom statistical test, P_val:5.828e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.041e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:7.054e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.121e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:4.396e-04
# Base_R vs. New_NB: Custom statistical test, P_val:3.764e-02
# New_NB vs. New_R: Custom statistical test, P_val:7.555e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.706e-03
# Base_R vs. New_R: Custom statistical test, P_val:3.598e-03
# Base_NB vs. New_R: Custom statistical test, P_val:2.109e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.133e-02
# Base_R vs. New_NB: Custom statistical test, P_val:8.501e-01
# New_NB vs. New_R: Custom statistical test, P_val:4.396e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:5.795e-03
# Base_R vs. New_R: Custom statistical test, P_val:5.828e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.000e+00
# Base_R vs. New_NB: Custom statistical test, P_val:1.817e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.806e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.806e-04
# Base_R vs. New_R: Custom statistical test, P_val:3.281e-04
# Base_NB vs. New_R: Custom statistical test, P_val:2.807e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:2.461e-04
# Base_R vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.620e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:6.229e-01
# Base_NB vs. New_R: Custom statistical test, P_val:1.000e+00
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:4.727e-01
# New_NB vs. New_R: Custom statistical test, P_val:7.566e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:7.285e-03
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:5.708e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.859e-01
# New_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:7.337e-01
# Base_R vs. New_R: Custom statistical test, P_val:1.706e-03
# Base_NB vs. New_R: Custom statistical test, P_val:1.706e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:6.232e-01
# Base_R vs. New_NB: Custom statistical test, P_val:9.698e-01
# New_NB vs. New_R: Custom statistical test, P_val:4.725e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:7.336e-01
# Base_R vs. New_R: Custom statistical test, P_val:4.495e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.847e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:3.121e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.575e-02
# Base_NB vs. New_R: Custom statistical test, P_val:9.097e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_NB: Custom statistical test, P_val:4.515e-02
# New_NB vs. New_R: Custom statistical test, P_val:7.566e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.133e-02
# Base_R vs. New_R: Custom statistical test, P_val:9.698e-01
# Base_NB vs. New_R: Custom statistical test, P_val:7.337e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.413e-01
# Base_R vs. New_NB: Custom statistical test, P_val:3.642e-01
# New_NB vs. New_R: Custom statistical test, P_val:6.776e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:7.337e-01
# Base_R vs. New_R: Custom statistical test, P_val:5.708e-01
# Base_NB vs. New_R: Custom statistical test, P_val:9.097e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:6.232e-01
# Base_R vs. New_NB: Custom statistical test, P_val:5.708e-01
# New_NB vs. New_R: Custom statistical test, P_val:6.776e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:6.776e-01
# Base_R vs. New_R: Custom statistical test, P_val:6.232e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.847e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:7.333e-01
# Base_R vs. New_NB: Custom statistical test, P_val:7.334e-01
# New_NB vs. New_R: Custom statistical test, P_val:3.573e-03
# Base_NB vs. New_NB: Custom statistical test, P_val:3.436e-01
# Base_R vs. New_R: Custom statistical test, P_val:7.132e-03
# Base_NB vs. New_R: Custom statistical test, P_val:3.231e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:3.075e-01
# Base_R vs. New_NB: Custom statistical test, P_val:7.285e-03
# New_NB vs. New_R: Custom statistical test, P_val:1.859e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:1.706e-03
# Base_R vs. New_R: Custom statistical test, P_val:7.566e-02
# Base_NB vs. New_R: Custom statistical test, P_val:2.202e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.413e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:3.611e-03
# Base_NB vs. New_R: Custom statistical test, P_val:5.828e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.730e-01
# Base_R vs. New_NB: Custom statistical test, P_val:5.795e-03
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:3.121e-02
# Base_R vs. New_R: Custom statistical test, P_val:4.586e-03
# Base_NB vs. New_R: Custom statistical test, P_val:3.298e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_NB: Custom statistical test, P_val:4.274e-01
# New_NB vs. New_R: Custom statistical test, P_val:1.008e-03
# Base_NB vs. New_NB: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_R: Custom statistical test, P_val:2.202e-03
# Base_NB vs. New_R: Custom statistical test, P_val:3.298e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:6.392e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.817e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:3.254e-01
# Base_NB vs. New_R: Custom statistical test, P_val:1.620e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:4.515e-02
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:9.082e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:2.817e-03
# Base_R vs. New_R: Custom statistical test, P_val:1.212e-01
# Base_NB vs. New_R: Custom statistical test, P_val:5.204e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:6.232e-01
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.730e-01
# Base_R vs. New_NB: Custom statistical test, P_val:4.396e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.133e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.212e-01
# Base_R vs. New_R: Custom statistical test, P_val:2.413e-01
# Base_NB vs. New_R: Custom statistical test, P_val:7.913e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.000e+00
# Base_R vs. New_NB: Custom statistical test, P_val:2.089e-02
# New_NB vs. New_R: Custom statistical test, P_val:1.035e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:8.927e-03
# Base_R vs. New_R: Custom statistical test, P_val:9.097e-01
# Base_NB vs. New_R: Custom statistical test, P_val:6.776e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.575e-02
# Base_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.405e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.040e-01
# New_NB vs. New_R: Custom statistical test, P_val:5.706e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_R: Custom statistical test, P_val:4.117e-02
# Base_NB vs. New_R: Custom statistical test, P_val:3.075e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.706e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.726e-02
# Base_R vs. New_R: Custom statistical test, P_val:9.097e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.611e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.413e-01
# Base_R vs. New_NB: Custom statistical test, P_val:4.586e-03
# New_NB vs. New_R: Custom statistical test, P_val:1.402e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:8.501e-01
# Base_NB vs. New_R: Custom statistical test, P_val:4.274e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.211e-01
# Base_R vs. New_NB: Custom statistical test, P_val:2.575e-02
# New_NB vs. New_R: Custom statistical test, P_val:4.556e-03
# Base_NB vs. New_NB: Custom statistical test, P_val:1.400e-01
# Base_R vs. New_R: Custom statistical test, P_val:4.051e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.102e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:3.298e-04
# Base_R vs. New_R: Custom statistical test, P_val:7.913e-01
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_NB: Custom statistical test, P_val:8.501e-01
# New_NB vs. New_R: Custom statistical test, P_val:3.847e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:5.966e-01
# Base_R vs. New_R: Custom statistical test, P_val:9.618e-02
# Base_NB vs. New_R: Custom statistical test, P_val:7.566e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:4.396e-04
# Base_R vs. New_NB: Custom statistical test, P_val:4.396e-04
# New_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.620e-01
# Base_R vs. New_R: Custom statistical test, P_val:3.075e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.298e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:9.698e-01
# Base_R vs. New_NB: Custom statistical test, P_val:2.575e-02
# New_NB vs. New_R: Custom statistical test, P_val:7.285e-03
# Base_NB vs. New_NB: Custom statistical test, P_val:2.575e-02
# Base_R vs. New_R: Custom statistical test, P_val:3.847e-01
# Base_NB vs. New_R: Custom statistical test, P_val:1.859e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.405e-01
# Base_R vs. New_NB: Custom statistical test, P_val:2.409e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.776e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:5.686e-03
# Base_R vs. New_R: Custom statistical test, P_val:2.411e-01
# Base_NB vs. New_R: Custom statistical test, P_val:2.569e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:4.396e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:3.298e-04
# Base_R vs. New_R: Custom statistical test, P_val:5.795e-03
# Base_NB vs. New_R: Custom statistical test, P_val:3.121e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.461e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.202e-03
# Base_NB vs. New_R: Custom statistical test, P_val:1.000e+00
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.575e-02
# Base_R vs. New_NB: Custom statistical test, P_val:5.390e-02
# New_NB vs. New_R: Custom statistical test, P_val:5.390e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.008e-03
# Base_R vs. New_R: Custom statistical test, P_val:6.776e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.447e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.827e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.008e-03
# New_NB vs. New_R: Custom statistical test, P_val:3.298e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:2.730e-01
# Base_R vs. New_R: Custom statistical test, P_val:2.123e-01
# Base_NB vs. New_R: Custom statistical test, P_val:5.828e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:6.402e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:4.571e-03
# Base_NB vs. New_R: Custom statistical test, P_val:4.725e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.461e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:8.897e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:3.847e-01
# Base_NB vs. New_R: Custom statistical test, P_val:6.232e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.575e-02
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.212e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:1.008e-03
# Base_NB vs. New_R: Custom statistical test, P_val:5.390e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:3.073e-01
# Base_R vs. New_NB: Custom statistical test, P_val:5.777e-03
# New_NB vs. New_R: Custom statistical test, P_val:6.775e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:6.776e-01
# Base_R vs. New_R: Custom statistical test, P_val:1.545e-02
# Base_NB vs. New_R: Custom statistical test, P_val:1.618e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.202e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:7.685e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:3.121e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.897e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.447e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:4.571e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.817e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:9.108e-03
# Base_R vs. New_R: Custom statistical test, P_val:2.569e-02
# Base_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:5.708e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.041e-01
# New_NB vs. New_R: Custom statistical test, P_val:7.685e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:4.515e-02
# Base_R vs. New_R: Custom statistical test, P_val:9.108e-03
# Base_NB vs. New_R: Custom statistical test, P_val:5.390e-02

# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sci_stats
from statannotations.Annotator import Annotator  # For adding statistical annotations

file_path_base_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_nb\metrics.json"
file_path_base_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\base_model\adjusted_scores\model_with_randomes\metrics.json"
file_path_new_nb = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_nb\metrics.json"
file_path_new_r = r"C:\Projects\grandmaster\notebooks\viterbi\mhc2\start9_end9\reculculation_with_length_devision\model_with_randomes\metrics.json"
file_path_mhcpred = r"C:\Projects\grandmaster\notebooks\mixmhc_metrics.json"

files = [file_path_base_nb, file_path_base_r, file_path_new_nb, file_path_new_r, file_path_mhcpred]

# Load metrics
def load_metrics(file_path):
    with open(file_path, "r") as f:
        return json.load(f)

# Dictionary to store metrics per allele
metrics_per_allele = {}
all_alleles = set()  # Keep track of all alleles seen
file_labels = {
    file_path_base_nb: "Base_NB",
    file_path_base_r: "Base_R",
    file_path_new_nb: "New_NB",
    file_path_new_r: "New_R",
    file_path_mhcpred: "MHCPred"
}

metric_name_mapping = {
    "auc_score": "auc"
}

# Collect all allele names first
for file_path in files:
    metrics = load_metrics(file_path)
    all_alleles.update(metrics.keys())  # Add alleles to the set

# Initialize data structure with all alleles
for allele in all_alleles:
    metrics_per_allele[allele] = []

# Process files and ensure all alleles exist in each dataset
for file_path in files:
    metrics = load_metrics(file_path)
    dataset_label = file_labels[file_path]

    for allele in all_alleles:
        folds = metrics.get(allele, [])  # Use an empty list if allele is missing

        for fold_idx, fold_data in enumerate(folds):
            if not isinstance(fold_data, dict):
                print(f"Unexpected format in {file_path} for allele {allele}: {type(fold_data)}")
                continue

            for metric, value in fold_data.items():
                base_metric = metric_name_mapping.get(metric, metric)  # Standardize metric names


                metrics_per_allele[allele].append({
                    "Metric": base_metric,
                    "Value": value,
                    "Dataset": dataset_label
                })

# Output directory
output_dir = r"C:\Projects\grandmaster\notebooks\plots\stars"
os.makedirs(output_dir, exist_ok=True)

# Generate plots
for allele, data in metrics_per_allele.items():
    df = pd.DataFrame(data)

    if df.empty:
        print(f"Skipping {allele} due to no data.")
        continue

    for metric in df["Metric"].unique():
        plt.figure(figsize=(10, 6))
        ax = sns.boxplot(x="Dataset", y="Value", data=df[df["Metric"] == metric])

        # Extract values for comparisons
        datasets = df["Dataset"].unique()
        dataset_pairs = [(datasets[i], datasets[j]) for i in range(len(datasets)) for j in range(i + 1, len(datasets))]

        # Compute p-values
        pvalues = [
            sci_stats.mannwhitneyu(
                df[(df["Dataset"] == pair[0]) & (df["Metric"] == metric)]["Value"],
                df[(df["Dataset"] == pair[1]) & (df["Metric"] == metric)]["Value"],
                alternative="two-sided"
            ).pvalue
            for pair in dataset_pairs
        ]

        # Format p-values
        def pval_to_stars(p):
            if p < 0.001:
                return "***"
            elif p < 0.01:
                return "**"
            elif p < 0.05:
                return "*"
            else:
                return "ns"

        stars = [pval_to_stars(p) for p in pvalues]

        # Add annotations
        annotator = Annotator(ax, dataset_pairs, data=df[df["Metric"] == metric], x="Dataset", y="Value")
        annotator.set_pvalues(pvalues)
        annotator.annotate()

        plt.title(f"{allele} - {metric}")
        plt.ylabel(metric)
        plt.xlabel("Dataset")
        plt.xticks(rotation=45)
        plt.savefig(os.path.join(output_dir, f"{allele}_{metric}.png"))
        plt.close()
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.040e-01
# Base_R vs. New_NB: Custom statistical test, P_val:3.281e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.817e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.388e-02
# Base_R vs. New_R: Custom statistical test, P_val:5.828e-04
# New_NB vs. MHCPred: Custom statistical test, P_val:4.375e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.817e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:5.205e-01
# Base_NB vs. MHCPred: Custom statistical test, P_val:2.411e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:4.274e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:3.298e-04
# Base_R vs. New_R: Custom statistical test, P_val:5.828e-04
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:4.396e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.041e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:7.054e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:3.121e-02
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:4.396e-04
# Base_R vs. New_NB: Custom statistical test, P_val:3.764e-02
# New_NB vs. New_R: Custom statistical test, P_val:7.555e-02
# New_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.706e-03
# Base_R vs. New_R: Custom statistical test, P_val:3.598e-03
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:2.109e-02
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:2.827e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.133e-02
# Base_R vs. New_NB: Custom statistical test, P_val:8.501e-01
# New_NB vs. New_R: Custom statistical test, P_val:4.396e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:5.795e-03
# Base_R vs. New_R: Custom statistical test, P_val:5.828e-04
# New_NB vs. MHCPred: Custom statistical test, P_val:2.827e-03
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:5.795e-03
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.041e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.000e+00
# Base_R vs. New_NB: Custom statistical test, P_val:1.817e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.806e-04
# New_R vs. MHCPred: Custom statistical test, P_val:5.204e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:1.806e-04
# Base_R vs. New_R: Custom statistical test, P_val:3.281e-04
# New_NB vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_R: Custom statistical test, P_val:2.807e-03
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:7.650e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:2.461e-04
# Base_R vs. New_R: Custom statistical test, P_val:1.827e-04
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.620e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:6.229e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.000e+00
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:4.727e-01
# New_NB vs. New_R: Custom statistical test, P_val:7.566e-02
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:7.285e-03
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:5.708e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.859e-01
# New_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# New_R vs. MHCPred: Custom statistical test, P_val:5.828e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:7.337e-01
# Base_R vs. New_R: Custom statistical test, P_val:1.706e-03
# New_NB vs. MHCPred: Custom statistical test, P_val:7.285e-03
# Base_NB vs. New_R: Custom statistical test, P_val:1.706e-03
# Base_R vs. MHCPred: Custom statistical test, P_val:8.501e-01
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.620e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:6.232e-01
# Base_R vs. New_NB: Custom statistical test, P_val:9.698e-01
# New_NB vs. New_R: Custom statistical test, P_val:4.725e-01
# New_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:7.336e-01
# Base_R vs. New_R: Custom statistical test, P_val:4.495e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.806e-04
# Base_NB vs. New_R: Custom statistical test, P_val:3.847e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.817e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:3.121e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.575e-02
# New_NB vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_R: Custom statistical test, P_val:9.097e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.817e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_NB: Custom statistical test, P_val:4.515e-02
# New_NB vs. New_R: Custom statistical test, P_val:7.566e-02
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.133e-02
# Base_R vs. New_R: Custom statistical test, P_val:9.698e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:7.337e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.413e-01
# Base_R vs. New_NB: Custom statistical test, P_val:3.642e-01
# New_NB vs. New_R: Custom statistical test, P_val:6.776e-01
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:7.337e-01
# Base_R vs. New_R: Custom statistical test, P_val:5.708e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:9.097e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:1.315e-03
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:6.232e-01
# Base_R vs. New_NB: Custom statistical test, P_val:5.708e-01
# New_NB vs. New_R: Custom statistical test, P_val:6.776e-01
# New_R vs. MHCPred: Custom statistical test, P_val:7.913e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:6.776e-01
# Base_R vs. New_R: Custom statistical test, P_val:6.232e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:9.097e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.847e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:7.337e-01
# Base_NB vs. MHCPred: Custom statistical test, P_val:5.708e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:7.333e-01
# Base_R vs. New_NB: Custom statistical test, P_val:7.334e-01
# New_NB vs. New_R: Custom statistical test, P_val:3.573e-03
# New_R vs. MHCPred: Custom statistical test, P_val:1.806e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:3.436e-01
# Base_R vs. New_R: Custom statistical test, P_val:7.132e-03
# New_NB vs. MHCPred: Custom statistical test, P_val:7.650e-04
# Base_NB vs. New_R: Custom statistical test, P_val:3.231e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.693e-03
# Base_NB vs. MHCPred: Custom statistical test, P_val:9.991e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:3.075e-01
# Base_R vs. New_NB: Custom statistical test, P_val:7.285e-03
# New_NB vs. New_R: Custom statistical test, P_val:1.859e-01
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.706e-03
# Base_R vs. New_R: Custom statistical test, P_val:7.566e-02
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:2.202e-03
# Base_R vs. MHCPred: Custom statistical test, P_val:3.298e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.008e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.413e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:9.108e-03
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:3.611e-03
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:5.828e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.730e-01
# Base_R vs. New_NB: Custom statistical test, P_val:5.795e-03
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:3.298e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:3.121e-02
# Base_R vs. New_R: Custom statistical test, P_val:4.586e-03
# New_NB vs. MHCPred: Custom statistical test, P_val:1.620e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.298e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:8.897e-02
# Base_NB vs. MHCPred: Custom statistical test, P_val:6.232e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_NB: Custom statistical test, P_val:4.274e-01
# New_NB vs. New_R: Custom statistical test, P_val:1.008e-03
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_R: Custom statistical test, P_val:2.202e-03
# New_NB vs. MHCPred: Custom statistical test, P_val:3.447e-01
# Base_NB vs. New_R: Custom statistical test, P_val:3.298e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.620e-01
# Base_NB vs. MHCPred: Custom statistical test, P_val:3.447e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:6.392e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.817e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:3.254e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.620e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:4.515e-02
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:9.082e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:2.817e-03
# Base_R vs. New_R: Custom statistical test, P_val:1.212e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:5.204e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.817e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:6.232e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.730e-01
# Base_R vs. New_NB: Custom statistical test, P_val:4.396e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.133e-02
# New_R vs. MHCPred: Custom statistical test, P_val:7.566e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.212e-01
# Base_R vs. New_R: Custom statistical test, P_val:2.413e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:3.847e-01
# Base_NB vs. New_R: Custom statistical test, P_val:7.913e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:2.461e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:4.727e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.000e+00
# Base_R vs. New_NB: Custom statistical test, P_val:2.089e-02
# New_NB vs. New_R: Custom statistical test, P_val:1.035e-01
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:8.927e-03
# Base_R vs. New_R: Custom statistical test, P_val:9.097e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.776e-04
# Base_NB vs. New_R: Custom statistical test, P_val:6.776e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:5.041e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.575e-02
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.315e-03
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.405e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.040e-01
# New_NB vs. New_R: Custom statistical test, P_val:5.706e-01
# New_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_R: Custom statistical test, P_val:4.117e-02
# New_NB vs. MHCPred: Custom statistical test, P_val:1.806e-04
# Base_NB vs. New_R: Custom statistical test, P_val:3.075e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:2.448e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.817e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.706e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:4.727e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:1.726e-02
# Base_R vs. New_R: Custom statistical test, P_val:9.097e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:3.611e-03
# Base_R vs. MHCPred: Custom statistical test, P_val:1.041e-01
# Base_NB vs. MHCPred: Custom statistical test, P_val:3.611e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.413e-01
# Base_R vs. New_NB: Custom statistical test, P_val:4.586e-03
# New_NB vs. New_R: Custom statistical test, P_val:1.402e-02
# New_R vs. MHCPred: Custom statistical test, P_val:5.708e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:8.501e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:4.274e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:2.413e-01
# Base_NB vs. MHCPred: Custom statistical test, P_val:9.097e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.211e-01
# Base_R vs. New_NB: Custom statistical test, P_val:2.575e-02
# New_NB vs. New_R: Custom statistical test, P_val:4.556e-03
# New_R vs. MHCPred: Custom statistical test, P_val:2.807e-03
# Base_NB vs. New_NB: Custom statistical test, P_val:1.400e-01
# Base_R vs. New_R: Custom statistical test, P_val:4.051e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:3.102e-02
# Base_R vs. MHCPred: Custom statistical test, P_val:1.008e-03
# Base_NB vs. MHCPred: Custom statistical test, P_val:3.281e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:2.113e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:3.298e-04
# Base_R vs. New_R: Custom statistical test, P_val:7.913e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.726e-02
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:8.501e-01
# Base_R vs. New_NB: Custom statistical test, P_val:8.501e-01
# New_NB vs. New_R: Custom statistical test, P_val:3.847e-01
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:5.966e-01
# Base_R vs. New_R: Custom statistical test, P_val:9.618e-02
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:7.566e-02
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:4.396e-04
# Base_R vs. New_NB: Custom statistical test, P_val:4.396e-04
# New_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# New_R vs. MHCPred: Custom statistical test, P_val:2.575e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:1.620e-01
# Base_R vs. New_R: Custom statistical test, P_val:3.075e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:7.685e-04
# Base_NB vs. New_R: Custom statistical test, P_val:3.298e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:3.075e-01
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.706e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:9.698e-01
# Base_R vs. New_NB: Custom statistical test, P_val:2.575e-02
# New_NB vs. New_R: Custom statistical test, P_val:7.285e-03
# New_R vs. MHCPred: Custom statistical test, P_val:4.274e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:2.575e-02
# Base_R vs. New_R: Custom statistical test, P_val:3.847e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:9.108e-03
# Base_NB vs. New_R: Custom statistical test, P_val:1.859e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:6.232e-01
# Base_NB vs. MHCPred: Custom statistical test, P_val:4.274e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.405e-01
# Base_R vs. New_NB: Custom statistical test, P_val:2.409e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.776e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:5.686e-03
# Base_R vs. New_R: Custom statistical test, P_val:2.411e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.293e-03
# Base_NB vs. New_R: Custom statistical test, P_val:2.569e-02
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:2.461e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:4.396e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:3.298e-04
# Base_R vs. New_R: Custom statistical test, P_val:5.795e-03
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:3.121e-02
# Base_R vs. MHCPred: Custom statistical test, P_val:2.461e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.461e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.202e-03
# New_NB vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.000e+00
# Base_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.817e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.575e-02
# Base_R vs. New_NB: Custom statistical test, P_val:5.390e-02
# New_NB vs. New_R: Custom statistical test, P_val:5.390e-02
# New_R vs. MHCPred: Custom statistical test, P_val:7.337e-01
# Base_NB vs. New_NB: Custom statistical test, P_val:1.008e-03
# Base_R vs. New_R: Custom statistical test, P_val:6.776e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:3.121e-02
# Base_NB vs. New_R: Custom statistical test, P_val:3.447e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:9.698e-01
# Base_NB vs. MHCPred: Custom statistical test, P_val:3.121e-02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.827e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.008e-03
# New_NB vs. New_R: Custom statistical test, P_val:3.298e-04
# New_R vs. MHCPred: Custom statistical test, P_val:3.121e-02
# Base_NB vs. New_NB: Custom statistical test, P_val:2.730e-01
# Base_R vs. New_R: Custom statistical test, P_val:2.123e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:7.685e-04
# Base_NB vs. New_R: Custom statistical test, P_val:5.828e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:8.897e-02
# Base_NB vs. MHCPred: Custom statistical test, P_val:9.108e-03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:6.402e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.817e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:4.571e-03
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:4.725e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.461e-04
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:8.897e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:3.847e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:6.232e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.575e-02
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:1.212e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.008e-03
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:1.008e-03
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:5.390e-02
# Base_R vs. MHCPred: Custom statistical test, P_val:3.075e-01
# Base_NB vs. MHCPred: Custom statistical test, P_val:2.413e-01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:3.073e-01
# Base_R vs. New_NB: Custom statistical test, P_val:5.777e-03
# New_NB vs. New_R: Custom statistical test, P_val:6.775e-01
# New_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:6.776e-01
# Base_R vs. New_R: Custom statistical test, P_val:1.545e-02
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.618e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:2.202e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:7.685e-04
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:3.121e-02
# Base_R vs. New_NB: Custom statistical test, P_val:1.827e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:1.827e-04
# Base_R vs. New_R: Custom statistical test, P_val:2.897e-01
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:3.447e-01
# Base_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:4.571e-03
# Base_R vs. New_NB: Custom statistical test, P_val:1.817e-04
# New_NB vs. New_R: Custom statistical test, P_val:1.827e-04
# New_R vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:9.108e-03
# Base_R vs. New_R: Custom statistical test, P_val:2.569e-02
# New_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# Base_NB vs. New_R: Custom statistical test, P_val:2.461e-04
# Base_R vs. MHCPred: Custom statistical test, P_val:1.817e-04
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.827e-04
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Base_NB vs. Base_R: Custom statistical test, P_val:5.708e-01
# Base_R vs. New_NB: Custom statistical test, P_val:1.041e-01
# New_NB vs. New_R: Custom statistical test, P_val:7.685e-04
# New_R vs. MHCPred: Custom statistical test, P_val:3.298e-04
# Base_NB vs. New_NB: Custom statistical test, P_val:4.515e-02
# Base_R vs. New_R: Custom statistical test, P_val:9.108e-03
# New_NB vs. MHCPred: Custom statistical test, P_val:5.390e-02
# Base_NB vs. New_R: Custom statistical test, P_val:5.390e-02
# Base_R vs. MHCPred: Custom statistical test, P_val:9.108e-03
# Base_NB vs. MHCPred: Custom statistical test, P_val:1.133e-02

# %%
metrics_per_allele
# Out:
# {'HLA-DRB501-01': [{'Metric': 'accuracy',
#    'Value': 0.7740384615384616,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8734793187347932, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8013392857142857, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8358556461001164, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8332741477272729, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7387820512820513, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8909574468085106, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7330415754923414, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8043217286914766, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8206213393781364, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.782051282051282, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.9122807017543859, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7827956989247312, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8425925925925926, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8602691553391493, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7644230769230769, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8833746898263027, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7807017543859649, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8288707799767171, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8354349415204678, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7724358974358975, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.9060913705583756, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7727272727272727, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8341121495327103, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8590200951312061, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7227564102564102, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8840970350404312, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7161572052401747, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7913148371531966, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8100897037933393, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7483974358974359, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8814432989690721, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7549668874172185, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8133174791914387, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8227928172159611, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7435897435897436, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.9142857142857143, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7348643006263048, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8148148148148148, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.7969476639550788, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7483974358974359, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8669950738916257, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7736263736263737, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8176538908246226, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8036868456986799, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7548076923076923, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8560975609756097, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7887640449438202, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8210526315789474, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8064842131692924, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7609170305676856, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7414529914529915, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7797752808988764, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.76013143483023, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8485603187098929, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.75764192139738, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7479338842975206, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7835497835497836, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7653276955602537, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8444323664587982, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7925764192139738, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.784, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8270042194092827, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8049281314168378, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8728640433778184, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7751091703056768, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7908366533864541, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7971887550200804, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.794, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8531590476739495, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7641921397379913, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7367256637168141, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7744186046511627, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7551020408163265, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8478179730117714, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7489082969432315, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7408207343412527, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7571743929359823, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7489082969432315, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8244627846990784, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7628415300546448, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7319148936170212, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7908045977011494, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7602209944751381, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.853941570881226, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7901639344262295, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7941834451901566, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7802197802197802, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7871396895787139, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8690826564739609, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7683060109289618, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7936842105263158, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7678207739307535, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7805383022774327, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8436094992890903, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7704918032786885, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7319587628865979, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8160919540229885, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7717391304347826, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.866044061302682, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7387820512820513, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9357798165137615, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6830357142857143, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7896774193548387, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8458172686688311, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7227564102564102, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9409937888198758, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6630196936542669, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7779204107830552, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8635726359097997, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7580128205128205, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9460227272727273, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.7161290322580646, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8151774785801713, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8565496720091972, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7323717948717948, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9093484419263456, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.7039473684210527, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7935723114956736, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8337510442773601, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7323717948717948, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9351032448377581, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6861471861471862, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7915106117353309, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8646852119074343, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7211538461538461, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.94375, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6593886462882096, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7763496143958869, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8622941547850792, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7451923076923077, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9273255813953488, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.7041942604856513, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8005018820577164, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8703510062868725, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7131410256410257, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9335260115606936, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6743215031315241, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7830303030303031, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8460010078468073, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7467948717948718, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9255014326647565, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.7098901098901099, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8034825870646766, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8538331490994212, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7355769230769231, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.940251572327044, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6719101123595506, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.783748361730013, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8474860335195531, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8155021834061136, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8108108108108109, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8089887640449438, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8098987626546682, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8819580619766694, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.7947598253275109, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8044444444444444, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7835497835497836, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.793859649122807, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8814148406659419, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8067685589519651, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.813953488372093, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8122362869198312, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8130939809926082, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8884099891173607, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.7936681222707423, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8351409978308026, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7730923694779116, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8029197080291971, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.875439557272151, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.834061135371179, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8293838862559242, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.813953488372093, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8215962441314554, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9004450186620729, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8034934497816594, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8053691275167785, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7947019867549668, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8778052722669605, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.825136612021858, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8175519630484989, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8137931034482758, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.815668202764977, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9089128352490422, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8032786885245902, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8089887640449438, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7912087912087912, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8782369804108935, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.7879781420765027, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8263736263736263, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7657841140529531, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.7949260042283298, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.862607116781309, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.7846994535519126, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.7819905213270142, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7586206896551724, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.7701283547257877, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8722078544061302, 'Dataset': 'New_R'}],
#  'HLA-DRB101-01': [{'Metric': 'accuracy',
#    'Value': 0.7478260869565218,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.9174630755864466, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7410526315789474, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8198757763975155, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8311824138659902, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7717391304347826, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.9286912751677853, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7676837725381415, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8405466970387244, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8462074589312721, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7706521739130435, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.9153122326775022, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7681263460157932, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8352849336455894, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8429539837249527, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7429347826086956, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8976982097186701, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7489331436699858, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8165955796820473, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8049578501615853, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7347826086956522, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.9133858267716536, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7285415212840195, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8105590062111802, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8131032129636456, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7396739130434783, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.905790838375108, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7390691114245416, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8139805825242719, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8242192461179553, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7326086956521739, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.903056768558952, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7307420494699647, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8078125, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.7991585948867179, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7478260869565218, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8949615713065756, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7544996400287977, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.81875, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8079844964952692, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.75, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.9072164948453608, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.75, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8211508553654744, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.824014066445707, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7438825448613376, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8966087675765095, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7580419580419581, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.821523304281925, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8009121685160805, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7432909604519774, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7247956403269755, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7671232876712328, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7453590192644484, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8202238781767425, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7387005649717514, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7375415282392026, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7628865979381443, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.75, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8192310091912545, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.713276836158192, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7219061166429588, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7068245125348189, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7142857142857143, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.7903021765330313, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7588276836158192, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.75, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7655913978494624, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7577155019510464, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8361440974950303, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7521186440677966, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7362491716368456, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7851590106007067, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7599179206566348, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8394403146048363, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7630649717514124, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7631763879128601, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7647887323943662, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7639817094618361, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8439048597534213, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7213983050847458, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7178619756427604, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7404047452896022, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7289591205771213, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8009564203720433, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7482344632768362, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7454050374404356, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7635983263598326, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7543920082673097, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8338042192173318, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7470858353938538, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7261987491313412, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.7644476956839795, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.744832501781896, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8231988599342024, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7559166372306605, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7510373443983402, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.766407904022583, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7586447782046805, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.832682849896039, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.6923913043478261, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9198435972629521, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6603508771929825, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7687908496732027, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8027588247727754, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.6864130434782608, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9472595656670114, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6352288488210819, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7604815276048152, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8348660779626288, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.6918478260869565, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9302083333333333, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6410624551328069, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7590310242243944, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8241527227058912, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.6695652173913044, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.933695652173913, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6109530583214794, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7386070507308684, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8101544729303644, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.6652173913043479, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9331919406150583, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6140963014654571, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7407407407407407, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.7949354543911418, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.6679347826086957, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9419496166484118, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6064880112834978, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7378807378807379, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8205711602350283, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.6755434782608696, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9416846652267818, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6162544169611307, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7449807774455361, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8123234254832675, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.6923913043478261, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9354497354497354, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6364290856731462, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7574978577549272, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.818054112212043, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.6934782608695652, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9368530020703933, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6427556818181818, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7624262847514743, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8096812855113635, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.6884176182707994, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9422084623323014, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6384615384615384, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7611504793664027, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8245550293227555, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7817796610169492, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.7829286239882266, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7671232876712328, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.7749453750910416, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8547017161332491, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.7623587570621468, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.7896296296296297, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7326460481099656, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.7600713012477719, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8403901104797271, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.7680084745762712, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8113509192645884, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7068245125348189, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.7554893933755117, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8448885993407347, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.7980225988700564, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8010241404535479, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7849462365591398, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.7929036929761043, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8756449492795374, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.7786016949152542, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.7966867469879518, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7477031802120141, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.7714181553044113, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.854026448152295, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.7612994350282486, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.7664756446991404, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7535211267605634, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.7599431818181818, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8314652076766548, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.763771186440678, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.7952086553323029, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7180739706908583, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.7546754675467546, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8382001499426117, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.763771186440678, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.79265493496557, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7224546722454672, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.7559284932506385, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8459674410345123, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.7813493465206641, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.7675250357653791, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7849305047549379, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.776130198915009, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8717885681621036, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.7855881314023313, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.7956204379562044, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7692307692307693, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.7822030857552924, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8590004781302809, 'Dataset': 'New_R'}],
#  'HLA-DRB301-01': [{'Metric': 'accuracy',
#    'Value': 0.8952991452991453,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.9288389513108615, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8920863309352518, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.9100917431192661, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.9614539946989777, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8504273504273504, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8909090909090909, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8596491228070176, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.875, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.931090020132298, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8888888888888888, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.910394265232975, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.9039145907473309, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.9071428571428571, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.953793746550707, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8803418803418803, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.9182879377431906, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8708487084870848, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8939393939393939, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.9451364564407065, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.892933618843683, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8961937716262975, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.9283154121863799, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.9119718309859155, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.960401891252955, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8715203426124197, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.898876404494382, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8791208791208791, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8888888888888888, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.9385597220648767, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8843683083511777, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.9100719424460432, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8971631205673759, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.9035714285714286, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.9328541307264712, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8351177730192719, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8385826771653543, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8554216867469879, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8469184890656064, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.9152573597140856, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.815845824411135, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8689138576779026, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8197879858657244, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8436363636363636, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8944346289752649, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8779443254817987, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.900398406374502, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.875968992248062, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.888015717092338, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.9331070805979007, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8978102189781022, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8768115942028986, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.9166666666666666, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8962962962962963, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.954518779342723, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8941605839416058, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.9103448275862069, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8918918918918919, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.9010238907849829, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.9554375804375803, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8394160583941606, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8661971830985915, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.831081081081081, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8482758620689655, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.9211845774345774, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8813868613138686, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8913857677902621, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8686131386861314, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8798521256931608, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.961439075070595, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.9014598540145985, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8836363636363637, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.9169811320754717, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.9, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.9685979065271019, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8832116788321168, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8576388888888888, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.9148148148148149, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8853046594982079, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.957300826005862, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8777372262773723, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8901515151515151, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8608058608058609, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8752327746741154, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.9177222777222777, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8503649635036497, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.864963503649635, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8404255319148937, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8525179856115108, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.9201861035567642, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8884826325411335, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8854961832061069, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8821292775665399, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8838095238095238, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.951132651421839, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8244972577696527, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8225806451612904, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.796875, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8095238095238095, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8946923324742266, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8717948717948718, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9541666666666667, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.8237410071942446, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8841698841698842, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.9506626277925029, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8568376068376068, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9325396825396826, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.8245614035087719, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8752327746741154, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.9270060396893874, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8782051282051282, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.948, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.8434163701067615, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8926553672316384, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.9480274801606181, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8739316239316239, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9774774774774775, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.8007380073800738, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8803245436105477, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.9395171109071496, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8650963597430407, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9354838709677419, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.8315412186379928, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8804554079696395, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.9406314344543583, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.9122055674518201, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.964, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.8827838827838828, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.9216061185468452, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.9536460103470413, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8650963597430407, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9397590361445783, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.8297872340425532, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8813559322033898, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.9395629672225417, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8972162740899358, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9427312775330396, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.8594377510040161, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8991596638655462, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.953391547842747, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8522483940042827, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9458333333333333, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.8021201413427562, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8680688336520076, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.9271777538792442, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8993576017130621, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.948936170212766, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.8643410852713178, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.9046653144016227, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.9399317532732465, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.9215328467153284, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.9201520912547528, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.9166666666666666, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.9184060721062619, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9737115877080667, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8613138686131386, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8767123287671232, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8648648648648649, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8707482993197279, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9425541613041613, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.885036496350365, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8949152542372881, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8918918918918919, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8934010152284264, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9531451093951093, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8540145985401459, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8849206349206349, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8138686131386861, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8479087452471483, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9209867334434441, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8667883211678832, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.875, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8452830188679246, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8598848368522073, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9344756317087805, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.9124087591240876, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8964285714285715, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.9296296296296296, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.9127272727272727, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9660005329070078, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.9142335766423357, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.9185185185185185, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.9084249084249084, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.9134438305709024, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9663936063936063, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8503649635036497, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.9, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7978723404255319, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8458646616541353, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9094544872820348, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8756855575868373, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.9012345679012346, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8326996197718631, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8656126482213439, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9219996786804477, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.9159049360146252, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.9338842975206612, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8828125, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.9076305220883534, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9605213702749141, 'Dataset': 'New_R'}],
#  'HLA-DRB401-01': [{'Metric': 'accuracy',
#    'Value': 0.7554858934169278,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7898089171974523, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7337278106508875, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7607361963190185, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8413017751479289, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7398119122257053, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7402597402597403, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7261146496815286, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7331189710610932, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8258237005583079, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.6990595611285266, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.6296296296296297, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7391304347826086, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.68, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.783609576427256, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7554858934169278, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7368421052631579, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7924528301886793, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7636363636363637, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8369300314465409, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7523510971786834, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7133333333333334, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7482517482517482, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7303754266211604, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8251748251748252, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7210031347962382, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.6709677419354839, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7323943661971831, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7003367003367004, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8087451261239755, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7210031347962382, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.6838235294117647, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.6690647482014388, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.6763636363636364, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.7693045563549161, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7115987460815048, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7152317880794702, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.6878980891719745, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7012987012987013, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8118660061335221, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7515723270440252, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7483870967741936, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7435897435897436, 'Dataset': 'Base_NB'},
# ...
#   {'Metric': 'precision', 'Value': 0.8405977584059776, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7894736842105263, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8142340168878166, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.898139534883721, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8058309037900875, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.7927590511860175, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7917705735660848, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.7922645040548971, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8899137697923865, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8011661807580175, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8096885813148789, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7995444191343963, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8045845272206303, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.8858979487975005, 'Dataset': 'New_R'}],
#  'HLA-DRB107-01': [{'Metric': 'accuracy',
#    'Value': 0.8362350380848749,
#    'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.8031591737545565, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.82625, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8145409735058533, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.9150903179190752, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8307943416757345, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7914572864321608, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8129032258064516, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8020369191597708, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.9032895335781266, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8329706202393906, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7913043478260869, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8208762886597938, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8058191018342821, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.9060619187683228, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7905331882480957, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7337962962962963, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8035487959442332, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7670901391409558, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8693758676559606, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8226332970620239, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7750294464075382, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8297604035308953, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8014616321559074, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.9080187284673912, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8335146898803046, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7927590511860175, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8193548387096774, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.8058375634517766, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.9034351955815859, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8117519042437432, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7737665463297232, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8027465667915106, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7879901960784313, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8923645346884379, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8073993471164309, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7514518002322881, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.8221092757306226, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7851941747572816, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8995208774362651, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.7834602829162133, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7199519230769231, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.7840314136125655, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7506265664160401, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8590811372078738, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8165487207403375, 'Dataset': 'Base_NB'},
#   {'Metric': 'precision', 'Value': 0.7852684144818977, 'Dataset': 'Base_NB'},
#   {'Metric': 'recall', 'Value': 0.792191435768262, 'Dataset': 'Base_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7887147335423198, 'Dataset': 'Base_NB'},
#   {'Metric': 'auc', 'Value': 0.8953959586640938, 'Dataset': 'Base_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8173138128580522, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8133498145859085, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8287153652392947, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8209606986899564, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8961970246605007, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8109484404837684, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8017565872020075, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8213367609254498, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8114285714285714, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8953471409537826, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8313176320814768, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8107784431137725, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8635204081632653, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8363187152563311, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.9112118481445944, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.7905792488860598, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7751256281407035, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8044328552803129, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.7895073576455535, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8674116380288908, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8173138128580522, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8063725490196079, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8360864040660737, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8209606986899564, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.9023043461348963, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.803946530872056, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8048192771084337, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8206388206388207, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8126520681265207, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8963141717434979, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8058561425843411, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.8037825059101655, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8302808302808303, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8168168168168168, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.882191242563583, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.81031190324634, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.796895213454075, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8137384412153237, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8052287581699347, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.9049688574127146, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8197452229299363, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.799475753604194, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8243243243243243, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8117099135063207, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.9031569521328557, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8006369426751593, 'Dataset': 'Base_R'},
#   {'Metric': 'precision', 'Value': 0.7929824561403509, 'Dataset': 'Base_R'},
#   {'Metric': 'recall', 'Value': 0.8329238329238329, 'Dataset': 'Base_R'},
#   {'Metric': 'f1_score', 'Value': 0.8124625524266027, 'Dataset': 'Base_R'},
#   {'Metric': 'auc', 'Value': 0.8785945035945035, 'Dataset': 'Base_R'},
#   {'Metric': 'accuracy', 'Value': 0.8286180631120783, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9061976549413735, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.67625, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7745168217609163, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.899315992292871, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8275299238302503, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9003496503496503, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6645161290322581, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7646622123236823, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8852225897490364, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8313384113166485, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.9175627240143369, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6597938144329897, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.767616191904048, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8920941571048595, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8215451577801959, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.8913412563667232, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6653992395437263, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7619738751814223, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8820006016956217, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.823721436343852, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.8914858096828047, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6733921815889029, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7672413793103449, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8939675509994751, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8269858541893362, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.8727569331158238, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6903225806451613, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.770893371757925, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8836360877613569, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8193688792165397, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.8954468802698144, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6629213483146067, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7618364418938307, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8731756471238339, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8280739934711643, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.8866995073891626, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6861499364675985, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7736389684813754, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8876111212531903, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8204570184983678, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.8780487804878049, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6596858638743456, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7533632286995515, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8785952109352912, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8149156232988568, 'Dataset': 'New_NB'},
#   {'Metric': 'precision', 'Value': 0.8834459459459459, 'Dataset': 'New_NB'},
#   {'Metric': 'recall', 'Value': 0.6586901763224181, 'Dataset': 'New_NB'},
#   {'Metric': 'f1_score', 'Value': 0.7546897546897547, 'Dataset': 'New_NB'},
#   {'Metric': 'auc', 'Value': 0.8799408797042053, 'Dataset': 'New_NB'},
#   {'Metric': 'accuracy', 'Value': 0.8446849140674729, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8489847715736041, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8425692695214105, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8457648546144121, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9260768505100999, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8472310630171865, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8674863387978142, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8161953727506427, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8410596026490066, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9308343895979279, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.852959898154042, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8576972833117723, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8456632653061225, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8516377649325626, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9250576977932214, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8255887969446213, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8409405255878285, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.7926988265971316, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8161073825503355, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9084466844396012, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8268618714194781, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8366013071895425, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8132147395171537, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8247422680412371, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.905497173456422, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8058561425843411, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8055222088835534, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8243243243243243, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8148148148148148, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.887330046511024, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8166772756206238, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8314606741573034, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8131868131868132, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8222222222222222, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.897318993063674, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8166772756206238, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.809775429326288, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.809775429326288, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.809775429326288, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9068740891726361, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8382165605095542, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8257372654155496, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8324324324324325, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.82907133243607, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9127271247150764, 'Dataset': 'New_R'},
#   {'Metric': 'accuracy', 'Value': 0.8222929936305733, 'Dataset': 'New_R'},
#   {'Metric': 'precision', 'Value': 0.8433889602053916, 'Dataset': 'New_R'},
#   {'Metric': 'recall', 'Value': 0.8071253071253072, 'Dataset': 'New_R'},
#   {'Metric': 'f1_score', 'Value': 0.8248587570621468, 'Dataset': 'New_R'},
#   {'Metric': 'auc', 'Value': 0.9056556556556556, 'Dataset': 'New_R'}]}

# %%
data
# Out:
# [{'Metric': 'accuracy', 'Value': 0.7740384615384616, 'Dataset': 'Base_NB'},
#  {'Metric': 'precision', 'Value': 0.8734793187347932, 'Dataset': 'Base_NB'},
#  {'Metric': 'recall', 'Value': 0.8013392857142857, 'Dataset': 'Base_NB'},
#  {'Metric': 'f1_score', 'Value': 0.8358556461001164, 'Dataset': 'Base_NB'},
#  {'Metric': 'auc', 'Value': 0.8332741477272729, 'Dataset': 'Base_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7387820512820513, 'Dataset': 'Base_NB'},
#  {'Metric': 'precision', 'Value': 0.8909574468085106, 'Dataset': 'Base_NB'},
#  {'Metric': 'recall', 'Value': 0.7330415754923414, 'Dataset': 'Base_NB'},
#  {'Metric': 'f1_score', 'Value': 0.8043217286914766, 'Dataset': 'Base_NB'},
#  {'Metric': 'auc', 'Value': 0.8206213393781364, 'Dataset': 'Base_NB'},
#  {'Metric': 'accuracy', 'Value': 0.782051282051282, 'Dataset': 'Base_NB'},
#  {'Metric': 'precision', 'Value': 0.9122807017543859, 'Dataset': 'Base_NB'},
#  {'Metric': 'recall', 'Value': 0.7827956989247312, 'Dataset': 'Base_NB'},
#  {'Metric': 'f1_score', 'Value': 0.8425925925925926, 'Dataset': 'Base_NB'},
#  {'Metric': 'auc', 'Value': 0.8602691553391493, 'Dataset': 'Base_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7644230769230769, 'Dataset': 'Base_NB'},
#  {'Metric': 'precision', 'Value': 0.8833746898263027, 'Dataset': 'Base_NB'},
#  {'Metric': 'recall', 'Value': 0.7807017543859649, 'Dataset': 'Base_NB'},
#  {'Metric': 'f1_score', 'Value': 0.8288707799767171, 'Dataset': 'Base_NB'},
#  {'Metric': 'auc', 'Value': 0.8354349415204678, 'Dataset': 'Base_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7724358974358975, 'Dataset': 'Base_NB'},
#  {'Metric': 'precision', 'Value': 0.9060913705583756, 'Dataset': 'Base_NB'},
#  {'Metric': 'recall', 'Value': 0.7727272727272727, 'Dataset': 'Base_NB'},
#  {'Metric': 'f1_score', 'Value': 0.8341121495327103, 'Dataset': 'Base_NB'},
#  {'Metric': 'auc', 'Value': 0.8590200951312061, 'Dataset': 'Base_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7227564102564102, 'Dataset': 'Base_NB'},
#  {'Metric': 'precision', 'Value': 0.8840970350404312, 'Dataset': 'Base_NB'},
#  {'Metric': 'recall', 'Value': 0.7161572052401747, 'Dataset': 'Base_NB'},
#  {'Metric': 'f1_score', 'Value': 0.7913148371531966, 'Dataset': 'Base_NB'},
#  {'Metric': 'auc', 'Value': 0.8100897037933393, 'Dataset': 'Base_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7483974358974359, 'Dataset': 'Base_NB'},
#  {'Metric': 'precision', 'Value': 0.8814432989690721, 'Dataset': 'Base_NB'},
#  {'Metric': 'recall', 'Value': 0.7549668874172185, 'Dataset': 'Base_NB'},
#  {'Metric': 'f1_score', 'Value': 0.8133174791914387, 'Dataset': 'Base_NB'},
#  {'Metric': 'auc', 'Value': 0.8227928172159611, 'Dataset': 'Base_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7435897435897436, 'Dataset': 'Base_NB'},
#  {'Metric': 'precision', 'Value': 0.9142857142857143, 'Dataset': 'Base_NB'},
#  {'Metric': 'recall', 'Value': 0.7348643006263048, 'Dataset': 'Base_NB'},
#  {'Metric': 'f1_score', 'Value': 0.8148148148148148, 'Dataset': 'Base_NB'},
#  {'Metric': 'auc', 'Value': 0.7969476639550788, 'Dataset': 'Base_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7483974358974359, 'Dataset': 'Base_NB'},
#  {'Metric': 'precision', 'Value': 0.8669950738916257, 'Dataset': 'Base_NB'},
#  {'Metric': 'recall', 'Value': 0.7736263736263737, 'Dataset': 'Base_NB'},
#  {'Metric': 'f1_score', 'Value': 0.8176538908246226, 'Dataset': 'Base_NB'},
#  {'Metric': 'auc', 'Value': 0.8036868456986799, 'Dataset': 'Base_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7548076923076923, 'Dataset': 'Base_NB'},
#  {'Metric': 'precision', 'Value': 0.8560975609756097, 'Dataset': 'Base_NB'},
#  {'Metric': 'recall', 'Value': 0.7887640449438202, 'Dataset': 'Base_NB'},
#  {'Metric': 'f1_score', 'Value': 0.8210526315789474, 'Dataset': 'Base_NB'},
#  {'Metric': 'auc', 'Value': 0.8064842131692924, 'Dataset': 'Base_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7609170305676856, 'Dataset': 'Base_R'},
#  {'Metric': 'precision', 'Value': 0.7414529914529915, 'Dataset': 'Base_R'},
#  {'Metric': 'recall', 'Value': 0.7797752808988764, 'Dataset': 'Base_R'},
#  {'Metric': 'f1_score', 'Value': 0.76013143483023, 'Dataset': 'Base_R'},
#  {'Metric': 'auc', 'Value': 0.8485603187098929, 'Dataset': 'Base_R'},
#  {'Metric': 'accuracy', 'Value': 0.75764192139738, 'Dataset': 'Base_R'},
#  {'Metric': 'precision', 'Value': 0.7479338842975206, 'Dataset': 'Base_R'},
#  {'Metric': 'recall', 'Value': 0.7835497835497836, 'Dataset': 'Base_R'},
#  {'Metric': 'f1_score', 'Value': 0.7653276955602537, 'Dataset': 'Base_R'},
#  {'Metric': 'auc', 'Value': 0.8444323664587982, 'Dataset': 'Base_R'},
#  {'Metric': 'accuracy', 'Value': 0.7925764192139738, 'Dataset': 'Base_R'},
#  {'Metric': 'precision', 'Value': 0.784, 'Dataset': 'Base_R'},
#  {'Metric': 'recall', 'Value': 0.8270042194092827, 'Dataset': 'Base_R'},
#  {'Metric': 'f1_score', 'Value': 0.8049281314168378, 'Dataset': 'Base_R'},
#  {'Metric': 'auc', 'Value': 0.8728640433778184, 'Dataset': 'Base_R'},
#  {'Metric': 'accuracy', 'Value': 0.7751091703056768, 'Dataset': 'Base_R'},
#  {'Metric': 'precision', 'Value': 0.7908366533864541, 'Dataset': 'Base_R'},
#  {'Metric': 'recall', 'Value': 0.7971887550200804, 'Dataset': 'Base_R'},
#  {'Metric': 'f1_score', 'Value': 0.794, 'Dataset': 'Base_R'},
#  {'Metric': 'auc', 'Value': 0.8531590476739495, 'Dataset': 'Base_R'},
#  {'Metric': 'accuracy', 'Value': 0.7641921397379913, 'Dataset': 'Base_R'},
#  {'Metric': 'precision', 'Value': 0.7367256637168141, 'Dataset': 'Base_R'},
#  {'Metric': 'recall', 'Value': 0.7744186046511627, 'Dataset': 'Base_R'},
#  {'Metric': 'f1_score', 'Value': 0.7551020408163265, 'Dataset': 'Base_R'},
#  {'Metric': 'auc', 'Value': 0.8478179730117714, 'Dataset': 'Base_R'},
#  {'Metric': 'accuracy', 'Value': 0.7489082969432315, 'Dataset': 'Base_R'},
#  {'Metric': 'precision', 'Value': 0.7408207343412527, 'Dataset': 'Base_R'},
#  {'Metric': 'recall', 'Value': 0.7571743929359823, 'Dataset': 'Base_R'},
#  {'Metric': 'f1_score', 'Value': 0.7489082969432315, 'Dataset': 'Base_R'},
#  {'Metric': 'auc', 'Value': 0.8244627846990784, 'Dataset': 'Base_R'},
#  {'Metric': 'accuracy', 'Value': 0.7628415300546448, 'Dataset': 'Base_R'},
#  {'Metric': 'precision', 'Value': 0.7319148936170212, 'Dataset': 'Base_R'},
#  {'Metric': 'recall', 'Value': 0.7908045977011494, 'Dataset': 'Base_R'},
#  {'Metric': 'f1_score', 'Value': 0.7602209944751381, 'Dataset': 'Base_R'},
#  {'Metric': 'auc', 'Value': 0.853941570881226, 'Dataset': 'Base_R'},
#  {'Metric': 'accuracy', 'Value': 0.7901639344262295, 'Dataset': 'Base_R'},
#  {'Metric': 'precision', 'Value': 0.7941834451901566, 'Dataset': 'Base_R'},
#  {'Metric': 'recall', 'Value': 0.7802197802197802, 'Dataset': 'Base_R'},
#  {'Metric': 'f1_score', 'Value': 0.7871396895787139, 'Dataset': 'Base_R'},
#  {'Metric': 'auc', 'Value': 0.8690826564739609, 'Dataset': 'Base_R'},
#  {'Metric': 'accuracy', 'Value': 0.7683060109289618, 'Dataset': 'Base_R'},
#  {'Metric': 'precision', 'Value': 0.7936842105263158, 'Dataset': 'Base_R'},
#  {'Metric': 'recall', 'Value': 0.7678207739307535, 'Dataset': 'Base_R'},
#  {'Metric': 'f1_score', 'Value': 0.7805383022774327, 'Dataset': 'Base_R'},
#  {'Metric': 'auc', 'Value': 0.8436094992890903, 'Dataset': 'Base_R'},
#  {'Metric': 'accuracy', 'Value': 0.7704918032786885, 'Dataset': 'Base_R'},
#  {'Metric': 'precision', 'Value': 0.7319587628865979, 'Dataset': 'Base_R'},
#  {'Metric': 'recall', 'Value': 0.8160919540229885, 'Dataset': 'Base_R'},
#  {'Metric': 'f1_score', 'Value': 0.7717391304347826, 'Dataset': 'Base_R'},
#  {'Metric': 'auc', 'Value': 0.866044061302682, 'Dataset': 'Base_R'},
#  {'Metric': 'accuracy', 'Value': 0.7387820512820513, 'Dataset': 'New_NB'},
#  {'Metric': 'precision', 'Value': 0.9357798165137615, 'Dataset': 'New_NB'},
#  {'Metric': 'recall', 'Value': 0.6830357142857143, 'Dataset': 'New_NB'},
#  {'Metric': 'f1_score', 'Value': 0.7896774193548387, 'Dataset': 'New_NB'},
#  {'Metric': 'auc', 'Value': 0.8458172686688311, 'Dataset': 'New_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7227564102564102, 'Dataset': 'New_NB'},
#  {'Metric': 'precision', 'Value': 0.9409937888198758, 'Dataset': 'New_NB'},
#  {'Metric': 'recall', 'Value': 0.6630196936542669, 'Dataset': 'New_NB'},
#  {'Metric': 'f1_score', 'Value': 0.7779204107830552, 'Dataset': 'New_NB'},
#  {'Metric': 'auc', 'Value': 0.8635726359097997, 'Dataset': 'New_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7580128205128205, 'Dataset': 'New_NB'},
#  {'Metric': 'precision', 'Value': 0.9460227272727273, 'Dataset': 'New_NB'},
#  {'Metric': 'recall', 'Value': 0.7161290322580646, 'Dataset': 'New_NB'},
#  {'Metric': 'f1_score', 'Value': 0.8151774785801713, 'Dataset': 'New_NB'},
#  {'Metric': 'auc', 'Value': 0.8565496720091972, 'Dataset': 'New_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7323717948717948, 'Dataset': 'New_NB'},
#  {'Metric': 'precision', 'Value': 0.9093484419263456, 'Dataset': 'New_NB'},
#  {'Metric': 'recall', 'Value': 0.7039473684210527, 'Dataset': 'New_NB'},
#  {'Metric': 'f1_score', 'Value': 0.7935723114956736, 'Dataset': 'New_NB'},
#  {'Metric': 'auc', 'Value': 0.8337510442773601, 'Dataset': 'New_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7323717948717948, 'Dataset': 'New_NB'},
#  {'Metric': 'precision', 'Value': 0.9351032448377581, 'Dataset': 'New_NB'},
#  {'Metric': 'recall', 'Value': 0.6861471861471862, 'Dataset': 'New_NB'},
#  {'Metric': 'f1_score', 'Value': 0.7915106117353309, 'Dataset': 'New_NB'},
#  {'Metric': 'auc', 'Value': 0.8646852119074343, 'Dataset': 'New_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7211538461538461, 'Dataset': 'New_NB'},
#  {'Metric': 'precision', 'Value': 0.94375, 'Dataset': 'New_NB'},
#  {'Metric': 'recall', 'Value': 0.6593886462882096, 'Dataset': 'New_NB'},
#  {'Metric': 'f1_score', 'Value': 0.7763496143958869, 'Dataset': 'New_NB'},
#  {'Metric': 'auc', 'Value': 0.8622941547850792, 'Dataset': 'New_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7451923076923077, 'Dataset': 'New_NB'},
#  {'Metric': 'precision', 'Value': 0.9273255813953488, 'Dataset': 'New_NB'},
#  {'Metric': 'recall', 'Value': 0.7041942604856513, 'Dataset': 'New_NB'},
#  {'Metric': 'f1_score', 'Value': 0.8005018820577164, 'Dataset': 'New_NB'},
#  {'Metric': 'auc', 'Value': 0.8703510062868725, 'Dataset': 'New_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7131410256410257, 'Dataset': 'New_NB'},
#  {'Metric': 'precision', 'Value': 0.9335260115606936, 'Dataset': 'New_NB'},
#  {'Metric': 'recall', 'Value': 0.6743215031315241, 'Dataset': 'New_NB'},
#  {'Metric': 'f1_score', 'Value': 0.7830303030303031, 'Dataset': 'New_NB'},
#  {'Metric': 'auc', 'Value': 0.8460010078468073, 'Dataset': 'New_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7467948717948718, 'Dataset': 'New_NB'},
#  {'Metric': 'precision', 'Value': 0.9255014326647565, 'Dataset': 'New_NB'},
#  {'Metric': 'recall', 'Value': 0.7098901098901099, 'Dataset': 'New_NB'},
#  {'Metric': 'f1_score', 'Value': 0.8034825870646766, 'Dataset': 'New_NB'},
#  {'Metric': 'auc', 'Value': 0.8538331490994212, 'Dataset': 'New_NB'},
#  {'Metric': 'accuracy', 'Value': 0.7355769230769231, 'Dataset': 'New_NB'},
#  {'Metric': 'precision', 'Value': 0.940251572327044, 'Dataset': 'New_NB'},
#  {'Metric': 'recall', 'Value': 0.6719101123595506, 'Dataset': 'New_NB'},
#  {'Metric': 'f1_score', 'Value': 0.783748361730013, 'Dataset': 'New_NB'},
#  {'Metric': 'auc', 'Value': 0.8474860335195531, 'Dataset': 'New_NB'},
#  {'Metric': 'accuracy', 'Value': 0.8155021834061136, 'Dataset': 'New_R'},
#  {'Metric': 'precision', 'Value': 0.8108108108108109, 'Dataset': 'New_R'},
#  {'Metric': 'recall', 'Value': 0.8089887640449438, 'Dataset': 'New_R'},
#  {'Metric': 'f1_score', 'Value': 0.8098987626546682, 'Dataset': 'New_R'},
#  {'Metric': 'auc', 'Value': 0.8819580619766694, 'Dataset': 'New_R'},
#  {'Metric': 'accuracy', 'Value': 0.7947598253275109, 'Dataset': 'New_R'},
#  {'Metric': 'precision', 'Value': 0.8044444444444444, 'Dataset': 'New_R'},
#  {'Metric': 'recall', 'Value': 0.7835497835497836, 'Dataset': 'New_R'},
#  {'Metric': 'f1_score', 'Value': 0.793859649122807, 'Dataset': 'New_R'},
#  {'Metric': 'auc', 'Value': 0.8814148406659419, 'Dataset': 'New_R'},
#  {'Metric': 'accuracy', 'Value': 0.8067685589519651, 'Dataset': 'New_R'},
#  {'Metric': 'precision', 'Value': 0.813953488372093, 'Dataset': 'New_R'},
#  {'Metric': 'recall', 'Value': 0.8122362869198312, 'Dataset': 'New_R'},
#  {'Metric': 'f1_score', 'Value': 0.8130939809926082, 'Dataset': 'New_R'},
#  {'Metric': 'auc', 'Value': 0.8884099891173607, 'Dataset': 'New_R'},
#  {'Metric': 'accuracy', 'Value': 0.7936681222707423, 'Dataset': 'New_R'},
#  {'Metric': 'precision', 'Value': 0.8351409978308026, 'Dataset': 'New_R'},
#  {'Metric': 'recall', 'Value': 0.7730923694779116, 'Dataset': 'New_R'},
#  {'Metric': 'f1_score', 'Value': 0.8029197080291971, 'Dataset': 'New_R'},
#  {'Metric': 'auc', 'Value': 0.875439557272151, 'Dataset': 'New_R'},
#  {'Metric': 'accuracy', 'Value': 0.834061135371179, 'Dataset': 'New_R'},
#  {'Metric': 'precision', 'Value': 0.8293838862559242, 'Dataset': 'New_R'},
#  {'Metric': 'recall', 'Value': 0.813953488372093, 'Dataset': 'New_R'},
#  {'Metric': 'f1_score', 'Value': 0.8215962441314554, 'Dataset': 'New_R'},
#  {'Metric': 'auc', 'Value': 0.9004450186620729, 'Dataset': 'New_R'},
#  {'Metric': 'accuracy', 'Value': 0.8034934497816594, 'Dataset': 'New_R'},
#  {'Metric': 'precision', 'Value': 0.8053691275167785, 'Dataset': 'New_R'},
#  {'Metric': 'recall', 'Value': 0.7947019867549668, 'Dataset': 'New_R'},
#  {'Metric': 'f1_score', 'Value': 0.8, 'Dataset': 'New_R'},
#  {'Metric': 'auc', 'Value': 0.8778052722669605, 'Dataset': 'New_R'},
#  {'Metric': 'accuracy', 'Value': 0.825136612021858, 'Dataset': 'New_R'},
#  {'Metric': 'precision', 'Value': 0.8175519630484989, 'Dataset': 'New_R'},
#  {'Metric': 'recall', 'Value': 0.8137931034482758, 'Dataset': 'New_R'},
#  {'Metric': 'f1_score', 'Value': 0.815668202764977, 'Dataset': 'New_R'},
#  {'Metric': 'auc', 'Value': 0.9089128352490422, 'Dataset': 'New_R'},
#  {'Metric': 'accuracy', 'Value': 0.8032786885245902, 'Dataset': 'New_R'},
#  {'Metric': 'precision', 'Value': 0.8089887640449438, 'Dataset': 'New_R'},
#  {'Metric': 'recall', 'Value': 0.7912087912087912, 'Dataset': 'New_R'},
#  {'Metric': 'f1_score', 'Value': 0.8, 'Dataset': 'New_R'},
#  {'Metric': 'auc', 'Value': 0.8782369804108935, 'Dataset': 'New_R'},
#  {'Metric': 'accuracy', 'Value': 0.7879781420765027, 'Dataset': 'New_R'},
#  {'Metric': 'precision', 'Value': 0.8263736263736263, 'Dataset': 'New_R'},
#  {'Metric': 'recall', 'Value': 0.7657841140529531, 'Dataset': 'New_R'},
#  {'Metric': 'f1_score', 'Value': 0.7949260042283298, 'Dataset': 'New_R'},
#  {'Metric': 'auc', 'Value': 0.862607116781309, 'Dataset': 'New_R'},
#  {'Metric': 'accuracy', 'Value': 0.7846994535519126, 'Dataset': 'New_R'},
#  {'Metric': 'precision', 'Value': 0.7819905213270142, 'Dataset': 'New_R'},
#  {'Metric': 'recall', 'Value': 0.7586206896551724, 'Dataset': 'New_R'},
#  {'Metric': 'f1_score', 'Value': 0.7701283547257877, 'Dataset': 'New_R'},
#  {'Metric': 'auc', 'Value': 0.8722078544061302, 'Dataset': 'New_R'}]
